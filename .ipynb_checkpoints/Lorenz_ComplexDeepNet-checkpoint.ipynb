# %%
# Plot of the Lorenz Attractor based on Edward Lorenz's 1963 "Deterministic
# Nonperiodic Flow" publication.
# http://journals.ametsoc.org/doi/abs/10.1175/1520-0469%281963%29020%3C0130%3ADNF%3E2.0.CO%3B2
#
import numpy as np
from scipy.integrate import odeint

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import matplotlib.gridspec as gridspec

# %% [markdown]
# ## Lorenz System
#
# The Lorenz Equations are a system of three coupled, first-order, nonlinear differential equations which describe the trajectory of a particle through time. The system was originally derived by Lorenz as a model of atmospheric convection, but the deceptive simplicity of the equations have made them an often-used example in fields beyond atmospheric physics.
#
# The equations describe the evolution of the spatial variables $x$, $y$, and $z$, given the governing parameters $\sigma$, $\beta$, and $\rho$, through the specification of the time-derivatives of the spatial variables:
#
# \begin{eqnarray}
# \dot{x} &= &\sigma(y-x)\\
# \dot{y} &= &(\rho-z)x - y\\
# \dot{z} &= &xy-\beta z
# \end{eqnarray}
#
# The resulting dynamics are entirely deterministic giving a starting point $(x_0, y_0, z_0)$ and a time interval $t$. Though it looks straightforward, for certain choices of the parameters $(\sigma, \rho, \beta)$, the trajectories become chaotic, and the resulting trajectories display some surprising properties. The system exhibits chaotic behaviour if all the three constants \($\sigma,\rho,\beta$) are set to specific values.
#
# \begin{eqnarray}
# \sigma &= &10\\
# \rho &= &28\\
# \beta &= &\frac{8}{3}
# \end{eqnarray}
#
# Though no general analytic solution exists for this system, the solutions can be computed numerically.  Python makes this sort of problem very easy to solve: one can simply use Scipy's interface to ODEPACK, an optimized Fortran package for solving ordinary differential equations.
#
# The above three equations characterize how the state derivatives \($\dot{x},\dot{y},\dot{z}$) depend on \($x,y,z$) and the constants \($\sigma,\rho,\beta$)\. The function below implements this, set some initial conditions, decide on a time array to simulate over, and run the simulation using odeint().
#
# Lorenz Attractor model is used to get simulated real-time vibration sensor data in a bearing.

# %%
def colorline3d(ax, x, y, z, cmap):
    N = len(x)
    skip = int(0.01*N)
    for i in range(0,N,skip):
        ax.plot(x[i:i+skip+1], y[i:i+skip+1], z[i:i+skip+1], color=cmap(int(255*i/N)))

    
# function that returns dx/dt
def f(x,t, sigma=10.0, beta=8.0/3.0, rho=28.0): # x is 3 x 1
        
    f1 = sigma*(x[1]-x[0])
    f2 = x[0]*(rho-x[2])-x[1]
    f3 = x[0]*x[1]-beta*x[2]
    f = np.array([f1,f2,f3])
    return f

def simulate(t_star, x0, noise, param_s=10.0, param_b=8.0/3.0, param_r=28.0):
    # solve ODE
    X_star = odeint(f, x0, t_star, args=(param_s, param_b, param_r))

    skip = 1
    dt = t_star[skip] - t_star[0]
    _data_sim = X_star[0::skip,:]
    _data_sim = _data_sim + noise*_data_sim.std(0)*np.random.randn(_data_sim.shape[0], _data_sim.shape[1])
    _data_sim = np.reshape(_data_sim, (_data_sim.shape[0],_data_sim.shape[1]))
    return _data_sim

# time points
time_points = np.arange(0,25,0.01)
    
# initial condition
x0 = np.array([-8.0, 7.0, 27])

_data_train = simulate(time_points, x0, 0)
_data_noise = simulate(time_points, x0, 0.3)
_data_test_one = simulate(time_points, x0, 0, 28.5, 2.2, 45)

# %% [markdown]
# ## Visually inspect the data

# %%
####### Plotting ################## 
def plotComparison(dataset1, title1, dataset2, title2):
    fig = plt.figure(figsize=(12, 8))
    ax = fig.gca(projection='3d')
    ax.axis('off')

    gs0 = gridspec.GridSpec(1, 2)
    gs0.update(top=0.95, bottom=0.1, left=0.0, right=0.90, wspace=0.15)

    ax = plt.subplot(gs0[:, 0:1], projection='3d')
    ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    colorline3d(ax, dataset1[:,0], dataset1[:,1], dataset1[:,2], cmap = plt.cm.ocean)
    ax.grid(False)
    ax.set_xlim([-20,20])
    ax.set_ylim([-50,50])
    ax.set_zlim([0,50])
    ax.set_xticks([-20,0,20])
    ax.set_yticks([-40,0,40])
    ax.set_zticks([0,25,50])
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')
    ax.set_title(title1, fontsize = 10)

    ax = plt.subplot(gs0[:, 1:2], projection='3d')
    ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))    
    colorline3d(ax, dataset2[:,0], dataset2[:,1], dataset2[:,2], cmap = plt.cm.ocean)
    ax.grid(False)
    ax.set_xlim([-20,20])
    ax.set_ylim([-50,50])
    ax.set_zlim([0,50])
    ax.set_xticks([-20,0,20])
    ax.set_yticks([-40,0,40])
    ax.set_zticks([0,25,50])
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')
    ax.set_title(title2, fontsize = 10)
    
plotComparison(_data_train, 'Exact Dynamics', _data_noise, 'Noisy Data')

# %%
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import Callback
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation, SimpleRNN
from keras.utils.vis_utils import plot_model
import pickle
# Out:
# /Users/ldalmeida/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# While this system oscillates between two semi-stable states, it is hard to identify any regular patterns

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(_data_train)
#ax.set_ylim(0,energy.max())
ax.plot(range(0,size), _data_train[:,0], '-', color='blue', animated = True, linewidth=1)
ax.plot(range(0,size), _data_train[:,1], '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,size), _data_train[:,2], '-', color='green', animated = True, linewidth=1)

# %% [markdown]
# ### Compare frequencies of healthy and noisy data

# %%
data_train_fft = np.fft.fft(_data_train)
data_noise_fft = np.fft.fft(_data_noise)

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(data_train_fft)
ax.plot(range(0,size), data_train_fft[:,0].real, '-', color='blue', animated = True, linewidth=1)
ax.plot(range(0,size), data_train_fft[:,1].imag, '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,size), data_train_fft[:,2].real, '-', color='green', animated = True, linewidth=1)

# %% [markdown]
# Note: I am plotting the imaginary part of the red dimension to see three lines because two dimensions on this dataset are completely overlapping in frequency and the real part is zero.
#
# It is evident that there are lot of frequencies present in noisy signal.

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(data_noise_fft)
ax.plot(range(0,size), data_noise_fft[:,0].real, '-', color='blue', animated = True, linewidth=1)
ax.plot(range(0,size), data_noise_fft[:,1].imag, '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,size), data_noise_fft[:,2].real, '-', color='green', animated = True, linewidth=1)

# %% [markdown]
# Based on research (the 2012 Stanford publication titled Deep Learning for Time Series Modeling by Enzo Busseti, Ian Osband, and Scott Wong), I will skip experimenting with deep feed-forward neural networks and directly start experimenting with a deep, recurrent neural network because it uses LSTM layers. Using LSTM layers is a way to introduce memory to neural networks that makes them ideal for analyzing time-series and sequence data.
# ### Data pre-processing for Keras neural networks

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler.fit_transform(_data_train)
X_noise_scaled = scaler.transform(_data_noise)

# %% [markdown]
# LSTMs want their input to contain windows of times. This way instead of 2500 samples per dimension we have 250 batches of length 10. Here, the objective is given the last 10 time steps of the signal predict the future 10.

# %%
timesteps = 10
dim = 3
samples = 2500
X_train_scaled = X_train_scaled.reshape(int(samples/timesteps),timesteps,dim)

# %%
losses = []
 
def handleLoss(loss):
        global losses
        losses+=[loss]
        print(loss)
 
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
 
    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        handleLoss(logs.get('loss'))

# %% [markdown]
# ### Simple Complex Recurrent Neural Network

# %%
from ComplexNets import *
from keras.layers import (Input, Reshape, Dense)
from keras.models import Model
from keras.optimizers import SGD
from keras.activations import relu
lamb = 0.03
epochs = 1000
lr = 1e-5
batch_size = 64
# Build neural network
def _complex_rnn_model_1():
    mod3 = Sequential()
    inp_3 = Input(shape=(timesteps, 2))
    lay_3 = ComplexDense(1, use_bias=False)(inp_3)
    out_3 = Amplitude()(lay_3)
    mod_3 = Model(inputs=inp_3, outputs=[out_3])

    mod_3.compile(optimizer=SGD(lr=lr), loss='mse', metrics=['mse',])
    mod_3.summary()
    return mod_3

# %%
model = _complex_rnn_model_1()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10, 2)             0
# _________________________________________________________________
# complex_dense_1 (ComplexDens (None, 1, 2)              20
# _________________________________________________________________
# amplitude_1 (Amplitude)      (None, 1)                 0
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %%
def _complex_rnn_model_2():
    mod3 = Sequential()
    inp_3 = Input(shape=(timesteps, 2))
    lay_3 = ComplexDense(50, use_bias=False, kernel_regularizer=regularizers.l2(0.01))(inp_3)
    
    out_3 = Amplitude()(lay_3)
    out_4 = Activation(relu)(out_3)
    out_5 = Dense(10, use_bias=False)(out_4)
    mod_3 = Model(inputs=inp_3, outputs=[out_5])

    mod_3.compile(optimizer=SGD(lr=lr), loss='mse', metrics=['mse',])
    mod_3.summary()
    return mod_3

# %%
model = _complex_rnn_model_2()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 10, 2)             0
# _________________________________________________________________
# complex_dense_2 (ComplexDens (None, 50, 2)             1000
# _________________________________________________________________
# amplitude_2 (Amplitude)      (None, 50)                0
# _________________________________________________________________
# activation_1 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                500
# =================================================================
# Total params: 1,500
# Trainable params: 1,500
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Generate sequence data to train the model

# %%
x_train_ch = real_to_channels_np(X_train_scaled[:,:,0].astype('float32'))
y_train = X_train_scaled[:,:,0]
x_train_comp = X_train_scaled[:,:,0].astype('complex64')

# %%
model.fit(x_train_ch, 
              y_train,
              validation_data = (x_train_ch, y_train),
              epochs = 1000,
              batch_size = 10,
              callbacks = [LossHistory()],
              shuffle = True,
             )
# Out:
# Train on 250 samples, validate on 250 samples
# Epoch 1/1000
#  10/250 [>.............................] - ETA: 4s - loss: 0.3859 - mean_squared_error: 0.34930.38587752
# 0.41458553
# 0.243604
# 0.439493
# 0.42724267
# 0.4109301
# 0.49083695
# 0.3944753
# 0.4224309
# 0.32528606
# 0.43418697
# 0.3064282
# 0.36900112
# 0.45989174
# 0.5439805
# 0.2339429
# 0.34494808
# 0.2811595
# 0.24455109
# 0.4313199
# 0.46086723
# 0.38103002
# 0.43921453
# 0.38216588
# 0.35465553
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3849 - mean_squared_error: 0.3483 - val_loss: 0.3847 - val_mean_squared_error: 0.3482
# Epoch 2/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.
1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.4060 - mean_squared_error: 0.36940.4059626
# 0.39318293
# 0.23957077
# 0.3513899
# 0.37659004
# 0.327667
# 0.2372907
# 0.41015232
# 0.40908462
# 0.51486593
# 0.4605149
# 0.24834274
# 0.41854435
# 0.44777972
# 0.31757042
# 0.3800907
# 0.333841
# 0.45432496
# 0.45082268
# 0.3307854
# 0.33903137
# 0.48156917
# 0.43300903
# 0.38644582
# 0.3688222
# 250/250 [==============================] - 0s 196us/step - loss: 0.3807 - mean_squared_error: 0.3441 - val_loss: 0.3806 - val_mean_squared_error: 0.3440
# Epoch 18/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.3343 - mean_squared_error: 0.29780.3343173
# 0.352709
# 0.35289714
# 0.27809054
# 0.4166353
# 0.28815112
# 0.4200037
# 0.36537918
# 0.3371059
# 0.2958195
# 0.36714977
# 0.38224047
# 0.37253878
# 0.39266658
# 0.43933305
# 0.5422494
# 0.37784272
# 0.4794156
# 0.4551081
# 0.43520936
# 0.44919008
# 0.25661737
# 0.38450393
# 0.3548717
# 0.38069507
# 250/250 [==============================] - 0s 238us/step - loss: 0.3804 - mean_squared_error: 0.3439 - val_loss: 0.3803 - val_mean_squared_error: 0.3437
# Epoch 19/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.3208 - mean_squared_error: 0.28430.32083493
# 0.54422593
# 0.40307137
# 0.4408847
# 0.3672248
# 0.5072866
# 0.30068064
# 0.32369357
# 0.43162933
# 0.38279298
# 0.37821603
# 0.40877423
# 0.31968197
# 0.3971988
# 0.3892998
# 0.43731332
# 0.3191182
# 0.47315395
# 0.23333398
# 0.32544687
# 0.20403081
# 0.342739
# 0.37893853
# 0.5012596
# 0.37340903
# 250/250 [==============================] - 0s 211us/step - loss: 0.3802 - mean_squared_error: 0.3436 - val_loss: 0.3800 - val_mean_squared_error: 0.3435
# Epoch 20/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.4803 - mean_squared_error: 0.44380.4803499
# 0.3793584
# 0.4583212
# 0.34972697
# 0.36813256
# 0.31673777
# 0.40340513
# 0.38926992
# 0.3933015
# 0.22730274
# 0.42610607
# 0.37621507
# 0.3170764
# 0.23321004
# 0.51800793
# 0.35024378
# 0.37418044
# 0.31485137
# 0.46603194
# 0.3928761
# 0.38326228
# 0.426288
# 0.4135589
# 0.35278845
# 0.38713586
# 250/250 [==============================] - 0s 203us/step - loss: 0.3799 - mean_squared_error: 0.3434 - val_loss: 0.3798 - val_mean_squared_error: 0.3432
# Epoch 21/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.3465 - mean_squared_error: 0.30990.34645683
# 0.32888073
# 0.35421956
# 0.31318453
# 0.36666793
# 0.42921966
# 0.3731876
# 0.3814104
# 0.35998416
# 0.27745816
# 0.34761217
# 0.31470188
# 0.25372142
# 0.4487246
# 0.3662679
# 0.47450653
# 0.42895994
# 0.3788348
# 0.34453505
# 0.48364115
# 0.38545895
# 0.52334476
# 0.43643484
# 0.3509756
# 0.4228554
# 250/250 [==============================] - 0s 205us/step - loss: 0.3796 - mean_squared_error: 0.3431 - val_loss: 0.3795 - val_mean_squared_error: 0.3430
# Epoch 22/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.3897 - mean_squared_error: 0.35320.38972056
# 0.29089928
# 0.35311294
# 0.5414173
# 0.4968003
# 0.34540802
# 0.45593736
# 0.29802456
# 0.34483695
# 0.45719373
# 0.35960886
# 0.34637722
# 0.3497173
# 0.35049695
# 0.38843814
# 0.18742698
# 0.42828587
# 0.32105064
# 0.35295144
# 0.44982883
# 0.27300635
# 0.43686694
# 0.45199546
# 0.44900092
# 0.36635563
# 250/250 [==============================] - 0s 201us/step - loss: 0.3794 - mean_squared_error: 0.3428 - val_loss: 0.3793 - val_mean_squared_error: 0.3427
# Epoch 23/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.
1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2988 - mean_squared_error: 0.26230.29880628
# 0.33312058
# 0.34231174
# 0.2863382
# 0.5170254
# 0.30095422
# 0.38934812
# 0.39370626
# 0.42201644
# 0.40341616
# 0.3260978
# 0.40322328
# 0.3135701
# 0.41229594
# 0.4385502
# 0.3146435
# 0.26694775
# 0.39485103
# 0.34595633
# 0.5051183
# 0.3225672
# 0.34177178
# 0.51068676
# 0.19281158
# 0.3720467
# 250/250 [==============================] - 0s 218us/step - loss: 0.3659 - mean_squared_error: 0.3294 - val_loss: 0.3658 - val_mean_squared_error: 0.3293
# Epoch 76/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2631 - mean_squared_error: 0.22660.26309967
# 0.24744895
# 0.3069276
# 0.29467678
# 0.25777727
# 0.3787806
# 0.35859516
# 0.35981816
# 0.39461622
# 0.22776546
# 0.3236623
# 0.3798798
# 0.33803645
# 0.439741
# 0.5086141
# 0.3338911
# 0.3912495
# 0.40431184
# 0.5236224
# 0.3823964
# 0.43810326
# 0.30527666
# 0.46857774
# 0.34263003
# 0.47246832
# 250/250 [==============================] - 0s 201us/step - loss: 0.3657 - mean_squared_error: 0.3291 - val_loss: 0.3655 - val_mean_squared_error: 0.3290
# Epoch 77/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.3993 - mean_squared_error: 0.36270.399259
# 0.30607384
# 0.5330318
# 0.30415183
# 0.5158514
# 0.36779594
# 0.34028417
# 0.38128942
# 0.38718075
# 0.42509192
# 0.40140137
# 0.30148104
# 0.41976094
# 0.4188972
# 0.37350747
# 0.42687222
# 0.32355404
# 0.32163894
# 0.2945141
# 0.35180295
# 0.3873279
# 0.30855596
# 0.3458982
# 0.17179376
# 0.32873893
# 250/250 [==============================] - 0s 222us/step - loss: 0.3654 - mean_squared_error: 0.3289 - val_loss: 0.3653 - val_mean_squared_error: 0.3288
# Epoch 78/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.3124 - mean_squared_error: 0.27590.3124072
# 0.37572706
# 0.31511497
# 0.37429714
# 0.39477727
# 0.3185923
# 0.38435033
# 0.28090778
# 0.4002022
# 0.440708
# 0.4711964
# 0.33832803
# 0.31677634
# 0.26395148
# 0.3515131
# 0.24530205
# 0.35226482
# 0.42948285
# 0.4817069
# 0.33908984
# 0.36247486
# 0.24309023
# 0.41138375
# 0.39084494
# 0.53505945
# 250/250 [==============================] - 0s 200us/step - loss: 0.3652 - mean_squared_error: 0.3287 - val_loss: 0.3651 - val_mean_squared_error: 0.3285
# Epoch 79/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.4434 - mean_squared_error: 0.40690.44339558
# 0.38632014
# 0.4167599
# 0.1639739
# 0.54199606
# 0.23696025
# 0.40637395
# 0.3356137
# 0.33150136
# 0.379559
# 0.30919203
# 0.53376335
# 0.31890282
# 0.23670417
# 0.31663245
# 0.28892127
# 0.3791061
# 0.39647004
# 0.40325782
# 0.33664662
# 0.42803308
# 0.35388356
# 0.31200102
# 0.43619153
# 0.4311915
# 250/250 [==============================] - 0s 238us/step - loss: 0.3649 - mean_squared_error: 0.3284 - val_loss: 0.3648 - val_mean_squared_error: 0.3283
# Epoch 80/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.
1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.4597 - mean_squared_error: 0.42320.45971933
# 0.36975834
# 0.36217391
# 0.37151212
# 0.40999183
# 0.39990976
# 0.21915737
# 0.24704231
# 0.32432318
# 0.3650344
# 0.29119682
# 0.41056463
# 0.28583768
# 0.59017634
# 0.2980864
# 0.3248875
# 0.320063
# 0.37737972
# 0.52398187
# 0.36713398
# 0.31507072
# 0.45403463
# 0.3958852
# 0.272502
# 0.29390588
# ...
# Epoch 971/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1930 - mean_squared_error: 0.15650.19299187
# 0.22060463
# 0.22368893
# 0.18890628
# 0.27564135
# 0.19782776
# 0.15848516
# 0.23304293
# 0.18953322
# 0.21926886
# 0.20771869
# 0.2701628
# 0.19258405
# 0.16550422
# 0.22625455
# 0.28878573
# 0.23976663
# 0.25309768
# 0.15088832
# 0.18800591
# 0.19158292
# 0.25105348
# 0.14396283
# 0.13647796
# 0.21932548
# 250/250 [==============================] - 0s 191us/step - loss: 0.2090 - mean_squared_error: 0.1725 - val_loss: 0.2089 - val_mean_squared_error: 0.1724
# Epoch 972/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2514 - mean_squared_error: 0.21490.25142294
# 0.25298932
# 0.22374034
# 0.19681923
# 0.2150124
# 0.14978108
# 0.205948
# 0.15997396
# 0.22848867
# 0.29475895
# 0.18756558
# 0.13079564
# 0.24519265
# 0.13612694
# 0.19701713
# 0.22688782
# 0.2379001
# 0.17393893
# 0.27499956
# 0.23013397
# 0.20129468
# 0.18224172
# 0.14798626
# 0.24449159
# 0.22675954
# 250/250 [==============================] - 0s 203us/step - loss: 0.2089 - mean_squared_error: 0.1724 - val_loss: 0.2088 - val_mean_squared_error: 0.1723
# Epoch 973/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1341 - mean_squared_error: 0.09760.13409838
# 0.17302719
# 0.198773
# 0.17352131
# 0.16358382
# 0.18728423
# 0.154551
# 0.2735415
# 0.1982954
# 0.21749607
# 0.17514005
# 0.20344537
# 0.15606797
# 0.30998543
# 0.22900054
# 0.2534856
# 0.27645087
# 0.19320989
# 0.21938744
# 0.22256288
# 0.26835895
# 0.2282433
# 0.17111172
# 0.22098002
# 0.21777216
# 250/250 [==============================] - 0s 198us/step - loss: 0.2088 - mean_squared_error: 0.1723 - val_loss: 0.2087 - val_mean_squared_error: 0.1722
# Epoch 974/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1682 - mean_squared_error: 0.13170.16823414
# 0.1813425
# 0.25657934
# 0.19067821
# 0.22617963
# 0.16277272
# 0.27308777
# 0.15072167
# 0.22202793
# 0.17904499
# 0.2059275
# 0.21796778
# 0.21415156
# 0.25537336
# 0.22386579
# 0.20111234
# 0.20218554
# 0.16760571
# 0.20616129
# 0.2272594
# 0.24133977
# 0.21234085
# 0.21225452
# 0.2510007
# 0.1672662
# 250/250 [==============================] - 0s 196us/step - loss: 0.2087 - mean_squared_error: 0.1722 - val_loss: 0.2086 - val_mean_squared_error: 0.1721
# Epoch 975/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2472 - mean_squared_error: 0.21060.2471545
# 0.23635057
# 0.21825308
# 0.29511023
# 0.21485667
# 0.16665342
# 0.20877494
# 0.27897063
# 0.22833699
# 0.16120553
# 0.23832548
# 0.17872718
# 0.2043904
# 0.21041627
# 0.22443831
# 0.24264312
# 0.20740756
# 0.21393035
# 0.15661456
# 0.19222091
# 0.11114083
# 0.20747453
# 0.17959857
# 0.230123
# 0.16047458
# 250/250 [==============================] - 0s 198us/step - loss: 0.2085 - mean_squared_error: 0.1720 - val_loss: 0.2085 - val_mean_squared_error: 0.1720
# Epoch 976/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2263 - mean_squared_error: 0.18980.22634722
# 0.2540689
# 0.15490189
# 0.16206977
# 0.2550366
# 0.26602536
# 0.2516995
# 0.22943118
# 0.24822259
# 0.16597176
# 0.19090451
# 0.25203317
# 0.16318578
# 0.2003144
# 0.18383531
# 0.18319371
# 0.15921763
# 0.20952064
# 0.15730274
# 0.20537648
# 0.22113822
# 0.21829933
# 0.20990595
# 0.21276864
# 0.22993365
# 250/250 [==============================] - 0s 226us/step - loss: 0.2084 - mean_squared_error: 0.1719 - val_loss: 0.2084 - val_mean_squared_error: 0.1719
# Epoch 977/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2153 - mean_squared_error: 0.17880.2153278
# 0.15362138
# 0.2083298
# 0.15313084
# 0.22292241
# 0.22332487
# 0.2013391
# 0.26356643
# 0.17476556
# 0.22396013
# 0.24255261
# 0.22706017
# 0.27893978
# 0.14238176
# 0.20774001
# 0.18866253
# 0.22681072
# 0.1847124
# 0.22748464
# 0.12768906
# 0.20379528
# 0.2660167
# 0.24674506
# 0.19822338
# 0.19871747
# 250/250 [==============================] - 0s 214us/step - loss: 0.2083 - mean_squared_error: 0.1718 - val_loss: 0.2083 - val_mean_squared_error: 0.1717
# Epoch 978/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2173 - mean_squared_error: 0.18070.21725541
# 0.2534411
# 0.24725705
# 0.2400912
# 0.18831179
# 0.18539017
# 0.15559845
# 0.23425806
# 0.17893037
# 0.25777727
# 0.21173978
# 0.1481688
# 0.14142893
# 0.16659188
# 0.20455223
# 0.22013064
# 0.18535292
# 0.32019824
# 0.19689965
# 0.1923084
# 0.20744795
# 0.1892436
# 0.23543413
# 0.17883232
# 0.2482957
# 250/250 [==============================] - 0s 204us/step - loss: 0.2082 - mean_squared_error: 0.1717 - val_loss: 0.2081 - val_mean_squared_error: 0.1716
# Epoch 979/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1828 - mean_squared_error: 0.14630.18284592
# 0.22918342
# 0.20635742
# 0.23077025
# 0.2246053
# 0.23904401
# 0.20476916
# 0.16930504
# 0.25914022
# 0.14236113
# 0.18275994
# 0.18495846
# 0.19075947
# 0.19950688
# 0.27934545
# 0.20052361
# 0.17472696
# 0.22460543
# 0.1692674
# 0.235776
# 0.19230378
# 0.20011225
# 0.17446697
# 0.24828881
# 0.2562695
# 250/250 [==============================] - 0s 203us/step - loss: 0.2081 - mean_squared_error: 0.1716 - val_loss: 0.2080 - val_mean_squared_error: 0.1715
# Epoch 980/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2549 - mean_squared_error: 0.21840.25490355
# 0.23182803
# 0.1910797
# 0.25835204
# 0.2635915
# 0.19477116
# 0.21336709
# 0.14022216
# 0.16752383
# 0.20179324
# 0.18489046
# 0.14205748
# 0.2184774
# 0.22891936
# 0.2869544
# 0.1982977
# 0.20790178
# 0.19675252
# 0.20258291
# 0.25365704
# 0.13036492
# 0.23415002
# 0.24505326
# 0.1825163
# 0.16916585
# 250/250 [==============================] - 0s 204us/step - loss: 0.2080 - mean_squared_error: 0.1715 - val_loss: 0.2079 - val_mean_squared_error: 0.1714
# Epoch 981/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.
1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1676 - mean_squared_error: 0.13100.16755146
# 0.2637476
# 0.1391044
# 0.23195916
# 0.19464327
# 0.23517005
# 0.1727666
# 0.1834976
# 0.22056037
# 0.24499908
# 0.20570385
# 0.22355583
# 0.23092401
# 0.24411851
# 0.24840412
# 0.13336042
# 0.1910927
# 0.20486796
# 0.2139739
# 0.25786257
# 0.21034935
# 0.19197643
# 0.19826046
# 0.17694294
# 0.19654217
# 250/250 [==============================] - 0s 197us/step - loss: 0.2073 - mean_squared_error: 0.1708 - val_loss: 0.2072 - val_mean_squared_error: 0.1707
# Epoch 987/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1712 - mean_squared_error: 0.13470.1711739
# 0.24814117
# 0.23430401
# 0.18924426
# 0.20795706
# 0.15434904
# 0.22837433
# 0.2614101
# 0.22721153
# 0.1640379
# 0.30990782
# 0.19176976
# 0.22152387
# 0.23788211
# 0.19869566
# 0.16361769
# 0.2144631
# 0.28858635
# 0.1839244
# 0.20832942
# 0.18340838
# 0.19099298
# 0.15452111
# 0.14564484
# 0.1995992
# 250/250 [==============================] - 0s 195us/step - loss: 0.2072 - mean_squared_error: 0.1707 - val_loss: 0.2071 - val_mean_squared_error: 0.1706
# Epoch 988/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2604 - mean_squared_error: 0.22390.2604389
# 0.24751078
# 0.2046276
# 0.18496253
# 0.255902
# 0.15977028
# 0.18471271
# 0.16448013
# 0.19408335
# 0.20709917
# 0.2132386
# 0.22883014
# 0.19355215
# 0.20488185
# 0.20720561
# 0.18584439
# 0.23910993
# 0.27037036
# 0.19038539
# 0.23503867
# 0.20089743
# 0.14627248
# 0.17428611
# 0.19600764
# 0.22669639
# 250/250 [==============================] - 0s 216us/step - loss: 0.2070 - mean_squared_error: 0.1705 - val_loss: 0.2070 - val_mean_squared_error: 0.1705
# Epoch 989/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2442 - mean_squared_error: 0.20760.24415821
# 0.13507518
# 0.21132153
# 0.15695861
# 0.22708559
# 0.24268165
# 0.16329254
# 0.14325315
# 0.16327663
# 0.16832286
# 0.23104712
# 0.16261378
# 0.15481839
# 0.21670616
# 0.21949485
# 0.17881072
# 0.19933845
# 0.24869312
# 0.19450441
# 0.23310827
# 0.25143367
# 0.24810155
# 0.25548977
# 0.32668978
# 0.19706798
# 250/250 [==============================] - 0s 194us/step - loss: 0.2069 - mean_squared_error: 0.1704 - val_loss: 0.2069 - val_mean_squared_error: 0.1704
# Epoch 990/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1944 - mean_squared_error: 0.15790.19443633
# 0.17039517
# 0.1958625
# 0.24984325
# 0.17781162
# 0.18226081
# 0.24865991
# 0.24305066
# 0.19409251
# 0.21480602
# 0.17545211
# 0.23780893
# 0.25225538
# 0.19113956
# 0.21831441
# 0.22731175
# 0.19902362
# 0.22871327
# 0.18358308
# 0.2397626
# 0.143758
# 0.19484644
# 0.21816748
# 0.23475465
# 0.15437204
# 250/250 [==============================] - 0s 196us/step - loss: 0.2068 - mean_squared_error: 0.1703 - val_loss: 0.2068 - val_mean_squared_error: 0.1702
# Epoch 991/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1434 - mean_squared_error: 0.10680.14335388
# 0.13004228
# 0.23000121
# 0.22399732
# 0.24014398
# 0.19061993
# 0.180987
# 0.24661367
# 0.18705827
# 0.23710933
# 0.20021906
# 0.2048583
# 0.25601897
# 0.19086763
# 0.23173544
# 0.17843848
# 0.120838
# 0.23408756
# 0.145452
# 0.24399602
# 0.23342179
# 0.27053097
# 0.26726454
# 0.19808906
# 0.18188073
# 250/250 [==============================] - 0s 192us/step - loss: 0.2067 - mean_squared_error: 0.1702 - val_loss: 0.2066 - val_mean_squared_error: 0.1701
# Epoch 992/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2535 - mean_squared_error: 0.21700.25351578
# 0.19051191
# 0.19938365
# 0.16845584
# 0.2202056
# 0.2686448
# 0.23615447
# 0.18487951
# 0.205879
# 0.21848378
# 0.18931095
# 0.2512054
# 0.16170013
# 0.26873302
# 0.21829668
# 0.1713586
# 0.13981752
# 0.16464636
# 0.2498995
# 0.24731876
# 0.19734922
# 0.28428727
# 0.19327185
# 0.13531135
# 0.14614733
# 250/250 [==============================] - 0s 196us/step - loss: 0.2066 - mean_squared_error: 0.1701 - val_loss: 0.2065 - val_mean_squared_error: 0.1700
# Epoch 993/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2893 - mean_squared_error: 0.25280.28934452
# 0.16602811
# 0.21558253
# 0.2225323
# 0.20706505
# 0.17349264
# 0.278297
# 0.18138567
# 0.12089714
# 0.18248774
# 0.19701423
# 0.18645903
# 0.19434065
# 0.19201875
# 0.19784416
# 0.1905644
# 0.21896304
# 0.2387208
# 0.18346226
# 0.21000937
# 0.24821538
# 0.19250762
# 0.15256862
# 0.32335716
# 0.19875607
# 250/250 [==============================] - 0s 204us/step - loss: 0.2065 - mean_squared_error: 0.1700 - val_loss: 0.2064 - val_mean_squared_error: 0.1699
# Epoch 994/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2064 - mean_squared_error: 0.16990.20644626
# 0.17875546
# 0.18812042
# 0.13564557
# 0.14639506
# 0.23238835
# 0.2574248
# 0.15476662
# 0.2266377
# 0.18037122
# 0.21651763
# 0.21801102
# 0.309376
# 0.2196219
# 0.17518377
# 0.1996435
# 0.20788796
# 0.21050943
# 0.13838929
# 0.23852025
# 0.18209502
# 0.22210276
# 0.23115903
# 0.2094563
# 0.27363575
# 250/250 [==============================] - 0s 203us/step - loss: 0.2064 - mean_squared_error: 0.1698 - val_loss: 0.2063 - val_mean_squared_error: 0.1698
# Epoch 995/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2126 - mean_squared_error: 0.17610.21261227
# 0.15060619
# 0.23134553
# 0.18620618
# 0.16127586
# 0.25867587
# 0.19971299
# 0.17777029
# 0.24581544
# 0.27084106
# 0.19413607
# 0.20938322
# 0.23251711
# 0.20217353
# 0.24387896
# 0.18969874
# 0.20968604
# 0.22711739
# 0.22277129
# 0.21193583
# 0.16787258
# 0.14345263
# 0.17460299
# 0.23121367
# 0.20090705
# 250/250 [==============================] - 0s 200us/step - loss: 0.2062 - mean_squared_error: 0.1697 - val_loss: 0.2062 - val_mean_squared_error: 0.1697
# Epoch 996/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1749 - mean_squared_error: 0.13830.17485224
# 0.22936818
# 0.22238375
# 0.23721035
# 0.23521332
# 0.21515046
# 0.21260706
# 0.2459692
# 0.1882595
# 0.265905
# 0.18534449
# 0.22029924
# 0.21842289
# 0.220212
# 0.23427323
# 0.18299446
# 0.17340988
# 0.17422502
# 0.20253214
# 0.15876995
# 0.20842542
# 0.19172521
# 0.20081738
# 0.1673536
# 0.18763503
# 250/250 [==============================] - 0s 219us/step - loss: 0.2061 - mean_squared_error: 0.1696 - val_loss: 0.2061 - val_mean_squared_error: 0.1696
# Epoch 997/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1790 - mean_squared_error: 0.14250.1790393
# 0.24763574
# 0.22219867
# 0.23327233
# 0.22970508
# 0.1929402
# 0.21171688
# 0.18131296
# 0.1675269
# 0.2324577
# 0.16321445
# 0.18352142
# 0.20602505
# 0.21071665
# 0.16713133
# 0.19510835
# 0.19032677
# 0.21088034
# 0.24631545
# 0.20897226
# 0.17043178
# 0.28725442
# 0.22407699
# 0.1603904
# 0.22834173
# 250/250 [==============================] - 0s 211us/step - loss: 0.2060 - mean_squared_error: 0.1695 - val_loss: 0.2060 - val_mean_squared_error: 0.1694
# Epoch 998/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.1493 - mean_squared_error: 0.11280.1492998
# 0.18359429
# 0.1744027
# 0.16635159
# 0.14200237
# 0.24319252
# 0.22381629
# 0.22412097
# 0.24015428
# 0.25801855
# 0.22681808
# 0.27796617
# 0.18794446
# 0.20046002
# 0.17893636
# 0.18179885
# 0.24037328
# 0.2259032
# 0.17053474
# 0.23640426
# 0.1964532
# 0.18629122
# 0.23798484
# 0.1909962
# 0.20385006
# 250/250 [==============================] - 0s 206us/step - loss: 0.2059 - mean_squared_error: 0.1694 - val_loss: 0.2058 - val_mean_squared_error: 0.1693
# Epoch 999/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2002 - mean_squared_error: 0.16370.20023906
# 0.23822932
# 0.23151755
# 0.20013785
# 0.19441892
# 0.24791348
# 0.15948682
# 0.20333567
# 0.20447278
# 0.14814332
# 0.2344093
# 0.24159838
# 0.19866018
# 0.2469396
# 0.17307234
# 0.22238122
# 0.2501909
# 0.18169822
# 0.28360775
# 0.1810273
# 0.16235176
# 0.22564036
# 0.14657477
# 0.18715142
# 0.18162756
# 250/250 [==============================] - 0s 207us/step - loss: 0.2058 - mean_squared_error: 0.1693 - val_loss: 0.2057 - val_mean_squared_error: 0.1692
# Epoch 1000/1000
#  10/250 [>.............................] - ETA: 0s - loss: 0.2107 - mean_squared_error: 0.17420.21069533
# 0.23837279
# 0.19301695
# 0.2339704
# 0.18671168
# 0.1705208
# 0.20280537
# 0.19661759
# 0.20725034
# 0.19348152
# 0.16154672
# 0.21380118
# 0.21307422
# 0.21358569
# 0.24044964
# 0.22208235
# 0.22295845
# 0.24195743
# 0.25505745
# 0.20161065
# 0.16608517
# 0.17145261
# 0.24138868
# 0.19330253
# 0.15018913
# 250/250 [==============================] - 0s 207us/step - loss: 0.2057 - mean_squared_error: 0.1692 - val_loss: 0.2056 - val_mean_squared_error: 0.1691

# %%
pred_test = model.predict(x_train_ch)
y_train.shape = (samples,)
pred_test.shape = (samples,)

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(pred_test)
ax.plot(range(0,size), y_train, '-', color='green', animated = True, linewidth=1)
ax.plot(range(0,size), pred_test, '-', color='red', animated = True, linewidth=1)
