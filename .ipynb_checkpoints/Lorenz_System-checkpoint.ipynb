# %%
# Plot of the Lorenz Attractor based on Edward Lorenz's 1963 "Deterministic
# Nonperiodic Flow" publication.
# http://journals.ametsoc.org/doi/abs/10.1175/1520-0469%281963%29020%3C0130%3ADNF%3E2.0.CO%3B2
#
import numpy as np
from scipy.integrate import odeint

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import matplotlib.gridspec as gridspec

# %% [markdown]
# ## Lorenz System
#
# The Lorenz Equations are a system of three coupled, first-order, nonlinear differential equations which describe the trajectory of a particle through time. The system was originally derived by Lorenz as a model of atmospheric convection, but the deceptive simplicity of the equations have made them an often-used example in fields beyond atmospheric physics.
#
# The equations describe the evolution of the spatial variables $x$, $y$, and $z$, given the governing parameters $\sigma$, $\beta$, and $\rho$, through the specification of the time-derivatives of the spatial variables:
#
# \begin{eqnarray}
# \dot{x} &= &\sigma(y-x)\\
# \dot{y} &= &(\rho-z)x - y\\
# \dot{z} &= &xy-\beta z
# \end{eqnarray}
#
# The resulting dynamics are entirely deterministic giving a starting point $(x_0, y_0, z_0)$ and a time interval $t$. Though it looks straightforward, for certain choices of the parameters $(\sigma, \rho, \beta)$, the trajectories become chaotic, and the resulting trajectories display some surprising properties. The system exhibits chaotic behaviour if all the three constants \($\sigma,\rho,\beta$) are set to specific values.
#
# \begin{eqnarray}
# \sigma &= &10\\
# \rho &= &28\\
# \beta &= &\frac{8}{3}
# \end{eqnarray}
#
# Though no general analytic solution exists for this system, the solutions can be computed numerically.  Python makes this sort of problem very easy to solve: one can simply use Scipy's interface to ODEPACK, an optimized Fortran package for solving ordinary differential equations.
#
# The above three equations characterize how the state derivatives \($\dot{x},\dot{y},\dot{z}$) depend on \($x,y,z$) and the constants \($\sigma,\rho,\beta$)\. The function below implements this, set some initial conditions, decide on a time array to simulate over, and run the simulation using odeint().
#
# Lorenz Attractor model is used to get simulated real-time vibration sensor data in a bearing.

# %%
def colorline3d(ax, x, y, z, cmap):
    N = len(x)
    skip = int(0.01*N)
    for i in range(0,N,skip):
        ax.plot(x[i:i+skip+1], y[i:i+skip+1], z[i:i+skip+1], color=cmap(int(255*i/N)))

    
# function that returns dx/dt
def f(x,t, sigma=10.0, beta=8.0/3.0, rho=28.0): # x is 3 x 1
        
    f1 = sigma*(x[1]-x[0])
    f2 = x[0]*(rho-x[2])-x[1]
    f3 = x[0]*x[1]-beta*x[2]
    f = np.array([f1,f2,f3])
    return f

def simulate(t_star, x0, noise, param_s=10.0, param_b=8.0/3.0, param_r=28.0):
    # solve ODE
    X_star = odeint(f, x0, t_star, args=(param_s, param_b, param_r))

    skip = 1
    dt = t_star[skip] - t_star[0]
    _data_sim = X_star[0::skip,:]
    _data_sim = _data_sim + noise*_data_sim.std(0)*np.random.randn(_data_sim.shape[0], _data_sim.shape[1])
    _data_sim = np.reshape(_data_sim, (_data_sim.shape[0],_data_sim.shape[1]))
    return _data_sim

# time points
time_points = np.arange(0,25,0.01)
    
# initial condition
x0 = np.array([-8.0, 7.0, 27])

_data_train = simulate(time_points, x0, 0)
_data_noise = simulate(time_points, x0, 0.3)
_data_test_one = simulate(time_points, x0, 0, 28.5, 2.2, 45)

# %% [markdown]
# ## Visually inspect the data

# %%
####### Plotting ################## 
def plotComparison(dataset1, title1, dataset2, title2):
    fig = plt.figure(figsize=(12, 8))
    ax = fig.gca(projection='3d')
    ax.axis('off')

    gs0 = gridspec.GridSpec(1, 2)
    gs0.update(top=0.95, bottom=0.1, left=0.0, right=0.90, wspace=0.15)

    ax = plt.subplot(gs0[:, 0:1], projection='3d')
    ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    colorline3d(ax, dataset1[:,0], dataset1[:,1], dataset1[:,2], cmap = plt.cm.ocean)
    ax.grid(False)
    ax.set_xlim([-20,20])
    ax.set_ylim([-50,50])
    ax.set_zlim([0,50])
    ax.set_xticks([-20,0,20])
    ax.set_yticks([-40,0,40])
    ax.set_zticks([0,25,50])
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')
    ax.set_title(title1, fontsize = 10)

    ax = plt.subplot(gs0[:, 1:2], projection='3d')
    ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
    ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))    
    colorline3d(ax, dataset2[:,0], dataset2[:,1], dataset2[:,2], cmap = plt.cm.ocean)
    ax.grid(False)
    ax.set_xlim([-20,20])
    ax.set_ylim([-50,50])
    ax.set_zlim([0,50])
    ax.set_xticks([-20,0,20])
    ax.set_yticks([-40,0,40])
    ax.set_zticks([0,25,50])
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')
    ax.set_title(title2, fontsize = 10)
    
plotComparison(_data_train, 'Exact Dynamics', _data_noise, 'Noisy Data')

# %%
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import Callback
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation, SimpleRNN
from keras.utils.vis_utils import plot_model
import pickle
# Out:
# /Users/ldalmeida/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import tensorflow as tf
import tflearn
import tensorflow.contrib.layers as tflayers
import tensorflow.contrib.metrics as metrics
import tensorflow.contrib.rnn as rnn
from ComplexRNN import ComplexRNNCell

# %% [markdown]
# While this system oscillates between two semi-stable states, it is hard to identify any regular patterns

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(_data_train)
#ax.set_ylim(0,energy.max())
ax.plot(range(0,size), _data_train[:,0], '-', color='blue', animated = True, linewidth=1)
ax.plot(range(0,size), _data_train[:,1], '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,size), _data_train[:,2], '-', color='green', animated = True, linewidth=1)

# %% [markdown]
# ### Compare frequencies of healthy and noisy data

# %%
data_train_fft = np.fft.fft(_data_train)
data_noise_fft = np.fft.fft(_data_noise)

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(data_train_fft)
ax.plot(range(0,size), data_train_fft[:,0].real, '-', color='blue', animated = True, linewidth=1)
ax.plot(range(0,size), data_train_fft[:,1].imag, '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,size), data_train_fft[:,2].real, '-', color='green', animated = True, linewidth=1)

# %% [markdown]
# Note: I am plotting the imaginary part of the red dimension to see three lines because two dimensions on this dataset are completely overlapping in frequency and the real part is zero.
#
# It is evident that there are lot of frequencies present in noisy signal.

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(data_noise_fft)
ax.plot(range(0,size), data_noise_fft[:,0].real, '-', color='blue', animated = True, linewidth=1)
ax.plot(range(0,size), data_noise_fft[:,1].imag, '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,size), data_noise_fft[:,2].real, '-', color='green', animated = True, linewidth=1)

# %% [markdown]
# ## Real valued neural networks

# %% [markdown]
# Based on research (the 2012 Stanford publication titled Deep Learning for Time Series Modeling by Enzo Busseti, Ian Osband, and Scott Wong), I will skip experimenting with deep feed-forward neural networks and directly start experimenting with a deep, recurrent neural network because it uses LSTM layers. Using LSTM layers is a way to introduce memory to neural networks that makes them ideal for analyzing time-series and sequence data.
# ### Data pre-processing for Keras neural networks

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler.fit_transform(_data_train)
X_noise_scaled = scaler.transform(_data_noise)

# %% [markdown]
# LSTMs want their input to contain windows of times. This way instead of 2500 samples per dimension we have 250 batches of length 10. Here, the objective is given the last 10 time steps of the signal predict the future 10.

# %%
timesteps = 10
dim = 3
samples = 2500
X_train_scaled = X_train_scaled.reshape(int(samples/timesteps),timesteps,dim)
X_noise_scaled = X_noise_scaled.reshape(int(samples/timesteps),timesteps,dim)

# %%
losses = []
 
def handleLoss(loss):
        global losses
        losses+=[loss]
        print(loss)
 
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
 
    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        handleLoss(logs.get('loss'))

# %% [markdown]
# ### Simple Sequential Model

# %%
# Build neural network
def _simple_sequential_model():
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(timesteps,dim)))
    model.add(Dropout(0.5))
    model.add(Dense(25, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(3, activation='relu'))

    # Compile model
    model.compile(optimizer='rmsprop',
                  loss='mse')
    return model

# %%
mod_1 = _simple_sequential_model()
print(mod_1.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10, 50)            200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 50)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10, 25)            1275
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 25)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10, 3)             78
# =================================================================
# Total params: 1,553
# Trainable params: 1,553
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Simple Recurrent Neural Network

# %%
# Build neural network
def _simple_rnn_model():
    model = Sequential()
    model.add(SimpleRNN(50,input_shape=(timesteps,dim),return_sequences=True))
    model.add(Dense(3))
    # Compile model
    model.compile(optimizer='adam',
                  loss='mean_squared_error')
    return model

# %%
mod_2 = _simple_rnn_model()
plot_model(mod_2, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
print(mod_2.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 10, 50)            2700
# _________________________________________________________________
# dense_4 (Dense)              (None, 10, 3)             153
# =================================================================
# Total params: 2,853
# Trainable params: 2,853
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### LSTM Neural Networks

# %%
from keras import regularizers
# design network
def _deep_lstm_model():
    model = Sequential()

    # test with 5 sequential layers
    # single layer with more units
    # weight reg and drop outs
    """model.add(LSTM(50,input_shape=(timesteps,dim),return_sequences=True, dropout=0.2, 
                   bias_regularizer=regularizers.l1(0.01)))"""
    model.add(LSTM(50,input_shape=(timesteps,dim),return_sequences=True))
    model.add(LSTM(50,input_shape=(timesteps,dim),return_sequences=True))
    model.add(LSTM(50,input_shape=(timesteps,dim),return_sequences=True))
    model.add(LSTM(50,input_shape=(timesteps,dim),return_sequences=True))
    model.add(LSTM(50,input_shape=(timesteps,dim),return_sequences=True))
    model.add(Dense(3))
    model.compile(loss='mae', optimizer='adam')
    return model

# %%
mod_3 = _deep_lstm_model()
print(mod_3.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 10, 50)            10800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 50)            20200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 50)            20200
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 10, 50)            20200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 10, 50)            20200
# _________________________________________________________________
# dense_5 (Dense)              (None, 10, 3)             153
# =================================================================
# Total params: 91,753
# Trainable params: 91,753
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
mod_1.fit(X_train_scaled, X_train_scaled,
        validation_data = (X_train_scaled, X_train_scaled),
        epochs = 50, batch_size = 72, callbacks = [LossHistory()], shuffle = False)
# Out:
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
#  72/250 [=======>......................] - ETA: 1s - loss: 0.27660.27659273
# 0.263528
# 0.23636733
# 0.17276444
# 250/250 [==============================] - 0s 2ms/step - loss: 0.2471 - val_loss: 0.2214
# Epoch 2/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.22950.2295191
# 0.22427583
# 0.19933231
# 0.14221145
# 250/250 [==============================] - 0s 59us/step - loss: 0.2074 - val_loss: 0.1843
# Epoch 3/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.19630.19626205
# 0.19078769
# 0.17216192
# 0.12030047
# 250/250 [==============================] - 0s 57us/step - loss: 0.1774 - val_loss: 0.1566
# Epoch 4/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.16930.16929296
# 0.1646842
# 0.14942996
# 0.10395243
# 250/250 [==============================] - 0s 59us/step - loss: 0.1534 - val_loss: 0.1293
# Epoch 5/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.15010.15010609
# 0.1436786
# 0.12804826
# 0.08730691
# 250/250 [==============================] - 0s 57us/step - loss: 0.1334 - val_loss: 0.0989
# Epoch 6/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.12330.12333957
# 0.12060335
# 0.10626568
# 0.07206804
# 250/250 [==============================] - 0s 56us/step - loss: 0.1107 - val_loss: 0.0729
# Epoch 7/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.10230.102258764
# 0.09965253
# 0.08845505
# 0.05892281
# 250/250 [==============================] - 0s 57us/step - loss: 0.0916 - val_loss: 0.0540
# Epoch 8/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.09040.090422824
# 0.08814288
# 0.07756632
# 0.057334155
# 250/250 [==============================] - 0s 60us/step - loss: 0.0816 - val_loss: 0.0402
# Epoch 9/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.07420.07421997
# 0.073905714
# 0.0717001
# 0.047987256
# 250/250 [==============================] - 0s 59us/step - loss: 0.0698 - val_loss: 0.0317
# Epoch 10/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.07110.07114747
# 0.062323887
# 0.06537705
# 0.052011695
# 250/250 [==============================] - 0s 63us/step - loss: 0.0643 - val_loss: 0.0261
# Epoch 11/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.06460.06461789
# 0.063712835
# 0.060006723
# 0.046431173
# 250/250 [==============================] - 0s 61us/step - loss: 0.0606 - val_loss: 0.0227
# Epoch 12/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.06090.060944412
# 0.060761902
# 0.057318322
# 0.045241777
# 250/250 [==============================] - 0s 59us/step - loss: 0.0577 - val_loss: 0.0204
# Epoch 13/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.05710.057071105
# 0.060018234
# 0.056747563
# 0.04286327
# 250/250 [==============================] - 0s 58us/step - loss: 0.0559 - val_loss: 0.0192
# Epoch 14/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.05470.05465959
# 0.05101194
# 0.050646033
# 0.039221082
# 250/250 [==============================] - 0s 59us/step - loss: 0.0504 - val_loss: 0.0183
# Epoch 15/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.05400.054037265
# 0.05216784
# 0.048976958
# 0.03862668
# 250/250 [==============================] - 0s 59us/step - loss: 0.0499 - val_loss: 0.0172
# Epoch 16/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.04990.04992196
# 0.049736533
# 0.050641328
# 0.040145915
# 250/250 [==============================] - 0s 65us/step - loss: 0.0487 - val_loss: 0.0156
# Epoch 17/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.04430.044343755
# 0.047369182
# 0.045084998
# 0.035903
# 250/250 [==============================] - 0s 65us/step - loss: 0.0443 - val_loss: 0.0139
# Epoch 18/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.04700.04702366
# 0.04382274
# 0.04321648
# 0.033970565
# 250/250 [==============================] - 0s 64us/step - loss: 0.0432 - val_loss: 0.0131
# Epoch 19/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.04340.043447286
# 0.041977443
# 0.04017728
# 0.029536359
# 250/250 [==============================] - 0s 63us/step - loss: 0.0402 - val_loss: 0.0133
# Epoch 20/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.04060.04056817
# 0.038771257
# 0.03978305
# 0.031777095
# 250/250 [==============================] - 0s 68us/step - loss: 0.0386 - val_loss: 0.0122
# Epoch 21/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.03970.03974362
# 0.03615474
# 0.037916858
# 0.025499538
# 250/250 [==============================] - 0s 65us/step - loss: 0.0362 - val_loss: 0.0112
# Epoch 22/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.03740.037365172
# 0.038891986
# 0.034813788
# 0.029173424
# 250/250 [==============================] - 0s 64us/step - loss: 0.0360 - val_loss: 0.0113
# Epoch 23/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.03460.034604024
# 0.036021214
# 0.03228907
# 0.027006766
# 250/250 [==============================] - 0s 61us/step - loss: 0.0333 - val_loss: 0.0113
# Epoch 24/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.03420.03420435
# 0.033547767
# 0.030804694
# 0.026018647
# 250/250 [==============================] - 0s 59us/step - loss: 0.0319 - val_loss: 0.0110
# Epoch 25/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.03340.033432126
# 0.03265752
# 0.033116985
# 0.02530081
# 250/250 [==============================] - 0s 63us/step - loss: 0.0320 - val_loss: 0.0108
# Epoch 26/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.03210.032106765
# 0.033959493
# 0.032390706
# 0.023716599
# 250/250 [==============================] - 0s 62us/step - loss: 0.0316 - val_loss: 0.0090
# Epoch 27/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.03040.03043587
# 0.03304075
# 0.029545201
# 0.023466654
# 250/250 [==============================] - 0s 61us/step - loss: 0.0300 - val_loss: 0.0100
# Epoch 28/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02960.029580712
# 0.030589249
# 0.029325664
# 0.019804629
# 250/250 [==============================] - 0s 64us/step - loss: 0.0285 - val_loss: 0.0100
# Epoch 29/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02940.029407693
# 0.028543707
# 0.025974551
# 0.022517195
# 250/250 [==============================] - 0s 61us/step - loss: 0.0272 - val_loss: 0.0090
# Epoch 30/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02700.026951753
# 0.02673285
# 0.025136111
# 0.018875958
# 250/250 [==============================] - 0s 63us/step - loss: 0.0253 - val_loss: 0.0084
# Epoch 31/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02920.029166989
# 0.027126329
# 0.025922628
# 0.019997412
# 250/250 [==============================] - 0s 59us/step - loss: 0.0264 - val_loss: 0.0092
# Epoch 32/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02590.02586813
# 0.026552541
# 0.025535366
# 0.018824887
# 250/250 [==============================] - 0s 60us/step - loss: 0.0250 - val_loss: 0.0087
# Epoch 33/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02570.025681784
# 0.024568804
# 0.024226837
# 0.019818095
# 250/250 [==============================] - 0s 67us/step - loss: 0.0241 - val_loss: 0.0074
# Epoch 34/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02370.023675667
# 0.02489873
# 0.023764016
# 0.017062271
# 250/250 [==============================] - 0s 65us/step - loss: 0.0232 - val_loss: 0.0078
# Epoch 35/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02390.023900995
# 0.02461536
# 0.022404045
# 0.017501786
# 250/250 [==============================] - 0s 65us/step - loss: 0.0228 - val_loss: 0.0078
# Epoch 36/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02250.022458177
# 0.02315081
# 0.021579744
# 0.015987387
# 250/250 [==============================] - 0s 68us/step - loss: 0.0215 - val_loss: 0.0072
# Epoch 37/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02320.023151644
# 0.023481822
# 0.020746924
# 0.015613079
# 250/250 [==============================] - 0s 63us/step - loss: 0.0215 - val_loss: 0.0066
# Epoch 38/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02220.022239206
# 0.02128158
# 0.020697674
# 0.016954016
# 250/250 [==============================] - 0s 70us/step - loss: 0.0208 - val_loss: 0.0069
# Epoch 39/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02050.020536926
# 0.021446072
# 0.022915488
# 0.016708307
# 250/250 [==============================] - 0s 62us/step - loss: 0.0210 - val_loss: 0.0062
# Epoch 40/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02080.020842101
# 0.020637967
# 0.019210327
# 0.015397988
# 250/250 [==============================] - 0s 69us/step - loss: 0.0196 - val_loss: 0.0061
# Epoch 41/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02180.021780428
# 0.019729383
# 0.020931993
# 0.015547316
# 250/250 [==============================] - 0s 62us/step - loss: 0.0201 - val_loss: 0.0057
# Epoch 42/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.01950.01951007
# 0.018855931
# 0.018799203
# 0.014751323
# 250/250 [==============================] - 0s 62us/step - loss: 0.0185 - val_loss: 0.0061
# Epoch 43/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.01870.018678473
# 0.018956354
# 0.017926063
# 0.015175134
# 250/250 [==============================] - 0s 61us/step - loss: 0.0181 - val_loss: 0.0058
# Epoch 44/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.01820.018240586
# 0.019112557
# 0.017470911
# 0.013167328
# 250/250 [==============================] - 0s 61us/step - loss: 0.0176 - val_loss: 0.0051
# Epoch 45/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.01860.018552471
# 0.016897444
# 0.018041572
# 0.014211563
# 250/250 [==============================] - 0s 60us/step - loss: 0.0173 - val_loss: 0.0057
# Epoch 46/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.01690.016933924
# 0.0178173
# 0.01661291
# 0.0137685025
# 250/250 [==============================] - 0s 67us/step - loss: 0.0167 - val_loss: 0.0071
# Epoch 47/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.02030.02029749
# 0.01745219
# 0.0167404
# 0.013150332
# 250/250 [==============================] - 0s 63us/step - loss: 0.0175 - val_loss: 0.0049
# Epoch 48/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.01690.01689896
# 0.01736209
# 0.01709554
# 0.012721615
# 250/250 [==============================] - 0s 67us/step - loss: 0.0165 - val_loss: 0.0043
# Epoch 49/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.01760.017588995
# 0.01704543
# 0.015830101
# 0.013514642
# 250/250 [==============================] - 0s 63us/step - loss: 0.0164 - val_loss: 0.0042
# Epoch 50/50
#  72/250 [=======>......................] - ETA: 0s - loss: 0.01750.017519359
# 0.016086007
# 0.015735997
# 0.012520576
# 250/250 [==============================] - 0s 61us/step - loss: 0.0159 - val_loss: 0.0043

# %% [markdown]
# The test and train phase of neural network is done twenty times with actual data and one time with noisy data. A spike is observed whenever the actual data pre-trained neural network sees noisy data.

# %%
for i in range(20):
     
    print("----------------actual samples")
    mod_2.fit(X_train_scaled, X_train_scaled,
        validation_data = (X_train_scaled, X_train_scaled),
        epochs = 50, batch_size = 72, shuffle = False)
    yhat_healthy = mod_2.predict(X_train_scaled)
    yhat_broken = mod_2.predict(X_noise_scaled)
    X_train_scaled.shape = (int(samples/timesteps),timesteps,dim)
    X_noise_scaled.shape = (int(samples/timesteps),timesteps,dim)

print("----------------noise")
mod_2.fit(X_noise_scaled, X_noise_scaled,
        validation_data = (X_noise_scaled, X_noise_scaled),
        epochs = 50, batch_size = 72, shuffle = False)
yhat_healthy = mod_2.predict(X_train_scaled)
yhat_broken = mod_2.predict(X_noise_scaled)
X_train_scaled.shape = (int(samples/timesteps),timesteps,dim)
X_noise_scaled.shape = (int(samples/timesteps),timesteps,dim)
# Out:
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.1556 - val_loss: 0.0802
# Epoch 2/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0741 - val_loss: 0.0671
# Epoch 3/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0631 - val_loss: 0.0512
# Epoch 4/50
# 250/250 [==============================] - 0s 91us/step - loss: 0.0468 - val_loss: 0.0396
# Epoch 5/50
# 250/250 [==============================] - 0s 91us/step - loss: 0.0380 - val_loss: 0.0353
# Epoch 6/50
# 250/250 [==============================] - 0s 90us/step - loss: 0.0342 - val_loss: 0.0312
# Epoch 7/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0297 - val_loss: 0.0263
# Epoch 8/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0252 - val_loss: 0.0229
# Epoch 9/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0223 - val_loss: 0.0208
# Epoch 10/50
# 250/250 [==============================] - 0s 94us/step - loss: 0.0202 - val_loss: 0.0187
# Epoch 11/50
# 250/250 [==============================] - 0s 89us/step - loss: 0.0180 - val_loss: 0.0166
# Epoch 12/50
# 250/250 [==============================] - 0s 91us/step - loss: 0.0161 - val_loss: 0.0152
# Epoch 13/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0148 - val_loss: 0.0139
# Epoch 14/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0136 - val_loss: 0.0127
# Epoch 15/50
# 250/250 [==============================] - 0s 91us/step - loss: 0.0123 - val_loss: 0.0115
# Epoch 16/50
# 250/250 [==============================] - 0s 91us/step - loss: 0.0112 - val_loss: 0.0105
# Epoch 17/50
# 250/250 [==============================] - 0s 91us/step - loss: 0.0103 - val_loss: 0.0096
# Epoch 18/50
# 250/250 [==============================] - 0s 90us/step - loss: 0.0094 - val_loss: 0.0088
# Epoch 19/50
# 250/250 [==============================] - 0s 101us/step - loss: 0.0086 - val_loss: 0.0080
# Epoch 20/50
# 250/250 [==============================] - 0s 100us/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 21/50
# 250/250 [==============================] - 0s 98us/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 22/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 23/50
# 250/250 [==============================] - 0s 94us/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 24/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 25/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 26/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 27/50
# 250/250 [==============================] - 0s 90us/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 28/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 29/50
# 250/250 [==============================] - 0s 94us/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 30/50
# 250/250 [==============================] - 0s 94us/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 31/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 32/50
# 250/250 [==============================] - 0s 96us/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 33/50
# 250/250 [==============================] - 0s 97us/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 34/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 35/50
# 250/250 [==============================] - 0s 98us/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 36/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 37/50
# 250/250 [==============================] - 0s 94us/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 38/50
# 250/250 [==============================] - 0s 96us/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 39/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 40/50
# 250/250 [==============================] - 0s 100us/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 41/50
# 250/250 [==============================] - 0s 101us/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 42/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 43/50
# 250/250 [==============================] - 0s 98us/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 44/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 45/50
# 250/250 [==============================] - 0s 96us/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 46/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 47/50
# 250/250 [==============================] - 0s 97us/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 48/50
# 250/250 [==============================] - 0s 97us/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 49/50
# 250/250 [==============================] - 0s 101us/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 50/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0016 - val_loss: 0.0016
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 94us/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 2/50
# 250/250 [==============================] - 0s 112us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 3/50
# 250/250 [==============================] - 0s 94us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 4/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 5/50
# 250/250 [==============================] - 0s 90us/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 6/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 7/50
# 250/250 [==============================] - 0s 94us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 8/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 9/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 10/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 11/50
# 250/250 [==============================] - 0s 97us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 12/50
# 250/250 [==============================] - 0s 91us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 13/50
# 250/250 [==============================] - 0s 90us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 14/50
# 250/250 [==============================] - 0s 89us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 15/50
# 250/250 [==============================] - 0s 91us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 16/50
# 250/250 [==============================] - 0s 96us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 17/50
# 250/250 [==============================] - 0s 93us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 18/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 19/50
# 250/250 [==============================] - 0s 91us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 20/50
# 250/250 [==============================] - 0s 92us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 21/50
# 250/250 [==============================] - 0s 100us/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 22/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 23/50
# 250/250 [==============================] - 0s 95us/step - loss: 0.0010 - val_loss: 9.9950e-04
# Epoch 24/50
# 250/250 [==============================] - 0s 94us/step - loss: 9.9501e-04 - val_loss: 9.8279e-04
# Epoch 25/50
# 250/250 [==============================] - 0s 95us/step - loss: 9.7844e-04 - val_loss: 9.6660e-04
# Epoch 26/50
# 250/250 [==============================] - 0s 95us/step - loss: 9.6240e-04 - val_loss: 9.5091e-04
# Epoch 27/50
# 250/250 [==============================] - 0s 97us/step - loss: 9.4685e-04 - val_loss: 9.3569e-04
# Epoch 28/50
# 250/250 [==============================] - 0s 92us/step - loss: 9.3177e-04 - val_loss: 9.2094e-04
# Epoch 29/50
# 250/250 [==============================] - 0s 104us/step - loss: 9.1714e-04 - val_loss: 9.0662e-04
# Epoch 30/50
# 250/250 [==============================] - 0s 90us/step - loss: 9.0295e-04 - val_loss: 8.9272e-04
# Epoch 31/50
# 250/250 [==============================] - 0s 95us/step - loss: 8.8916e-04 - val_loss: 8.7921e-04
# Epoch 32/50
# 250/250 [==============================] - 0s 105us/step - loss: 8.7577e-04 - val_loss: 8.6610e-04
# Epoch 33/50
# 250/250 [==============================] - 0s 103us/step - loss: 8.6276e-04 - val_loss: 8.5335e-04
# Epoch 34/50
# 250/250 [==============================] - 0s 89us/step - loss: 8.5012e-04 - val_loss: 8.4095e-04
# Epoch 35/50
# 250/250 [==============================] - 0s 96us/step - loss: 8.3782e-04 - val_loss: 8.2889e-04
# Epoch 36/50
# 250/250 [==============================] - 0s 92us/step - loss: 8.2586e-04 - val_loss: 8.1716e-04
# Epoch 37/50
# 250/250 [==============================] - 0s 98us/step - loss: 8.1421e-04 - val_loss: 8.0573e-04
# Epoch 38/50
# 250/250 [==============================] - 0s 96us/step - loss: 8.0288e-04 - val_loss: 7.9460e-04
# Epoch 39/50
# 250/250 [==============================] - 0s 104us/step - loss: 7.9183e-04 - val_loss: 7.8376e-04
# Epoch 40/50
# 250/250 [==============================] - 0s 94us/step - loss: 7.8106e-04 - val_loss: 7.7319e-04
# Epoch 41/50
# 250/250 [==============================] - 0s 97us/step - loss: 7.7057e-04 - val_loss: 7.6288e-04
# Epoch 42/50
# 250/250 [==============================] - 0s 92us/step - loss: 7.6034e-04 - val_loss: 7.5283e-04
# Epoch 43/50
# 250/250 [==============================] - 0s 95us/step - loss: 7.5036e-04 - val_loss: 7.4303e-04
# Epoch 44/50
# 250/250 [==============================] - 0s 93us/step - loss: 7.4062e-04 - val_loss: 7.3345e-04
# Epoch 45/50
# 250/250 [==============================] - 0s 92us/step - loss: 7.3111e-04 - val_loss: 7.2411e-04
# Epoch 46/50
# 250/250 [==============================] - 0s 90us/step - loss: 7.2183e-04 - val_loss: 7.1498e-04
# Epoch 47/50
# 250/250 [==============================] - 0s 89us/step - loss: 7.1277e-04 - val_loss: 7.0607e-04
# Epoch 48/50
# 250/250 [==============================] - 0s 90us/step - loss: 7.0392e-04 - val_loss: 6.9736e-04
# Epoch 49/50
# 250/250 [==============================] - 0s 91us/step - loss: 6.9526e-04 - val_loss: 6.8885e-04
# Epoch 50/50
# 250/250 [==============================] - 0s 97us/step - loss: 6.8680e-04 - val_loss: 6.8052e-04
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 100us/step - loss: 6.7853e-04 - val_loss: 6.7238e-04
# Epoch 2/50
# 250/250 [==============================] - 0s 105us/step - loss: 6.7045e-04 - val_loss: 6.6442e-04
# Epoch 3/50
# 250/250 [==============================] - 0s 97us/step - loss: 6.6253e-04 - val_loss: 6.5662e-04
# Epoch 4/50
# 250/250 [==============================] - 0s 95us/step - loss: 6.5479e-04 - val_loss: 6.4900e-04
# Epoch 5/50
# 250/250 [==============================] - 0s 103us/step - loss: 6.4721e-04 - val_loss: 6.4154e-04
# Epoch 6/50
# 250/250 [==============================] - 0s 98us/step - loss: 6.3979e-04 - val_loss: 6.3423e-04
# Epoch 7/50
# 250/250 [==============================] - 0s 108us/step - loss: 6.3252e-04 - val_loss: 6.2707e-04
# Epoch 8/50
# 250/250 [==============================] - 0s 104us/step - loss: 6.2541e-04 - val_loss: 6.2006e-04
# Epoch 9/50
# 250/250 [==============================] - 0s 97us/step - loss: 6.1844e-04 - val_loss: 6.1319e-04
# Epoch 10/50
# 250/250 [==============================] - 0s 92us/step - loss: 6.1161e-04 - val_loss: 6.0646e-04
# Epoch 11/50
# 250/250 [==============================] - 0s 87us/step - loss: 6.0492e-04 - val_loss: 5.9986e-04
# Epoch 12/50
# 250/250 [==============================] - 0s 91us/step - loss: 5.9836e-04 - val_loss: 5.9339e-04
# Epoch 13/50
# 250/250 [==============================] - 0s 89us/step - loss: 5.9192e-04 - val_loss: 5.8705e-04
# Epoch 14/50
# 250/250 [==============================] - 0s 92us/step - loss: 5.8562e-04 - val_loss: 5.8084e-04
# Epoch 15/50
# 250/250 [==============================] - 0s 91us/step - loss: 5.7943e-04 - val_loss: 5.7474e-04
# Epoch 16/50
# 250/250 [==============================] - 0s 95us/step - loss: 5.7337e-04 - val_loss: 5.6875e-04
# Epoch 17/50
# 250/250 [==============================] - 0s 90us/step - loss: 5.6742e-04 - val_loss: 5.6288e-04
# Epoch 18/50
# 250/250 [==============================] - 0s 91us/step - loss: 5.6158e-04 - val_loss: 5.5712e-04
# Epoch 19/50
# 250/250 [==============================] - 0s 91us/step - loss: 5.5584e-04 - val_loss: 5.5146e-04
# Epoch 20/50
# 250/250 [==============================] - 0s 90us/step - loss: 5.5022e-04 - val_loss: 5.4591e-04
# Epoch 21/50
# 250/250 [==============================] - 0s 94us/step - loss: 5.4469e-04 - val_loss: 5.4046e-04
# Epoch 22/50
# 250/250 [==============================] - 0s 91us/step - loss: 5.3927e-04 - val_loss: 5.3511e-04
# Epoch 23/50
# 250/250 [==============================] - 0s 88us/step - loss: 5.3394e-04 - val_loss: 5.2985e-04
# Epoch 24/50
# 250/250 [==============================] - 0s 89us/step - loss: 5.2871e-04 - val_loss: 5.2468e-04
# Epoch 25/50
# 250/250 [==============================] - 0s 89us/step - loss: 5.2357e-04 - val_loss: 5.1961e-04
# Epoch 26/50
# 250/250 [==============================] - 0s 91us/step - loss: 5.1852e-04 - val_loss: 5.1462e-04
# Epoch 27/50
# 250/250 [==============================] - 0s 95us/step - loss: 5.1356e-04 - val_loss: 5.0972e-04
# Epoch 28/50
# 250/250 [==============================] - 0s 90us/step - loss: 5.0868e-04 - val_loss: 5.0491e-04
# Epoch 29/50
# 250/250 [==============================] - 0s 94us/step - loss: 5.0389e-04 - val_loss: 5.0017e-04
# Epoch 30/50
# 250/250 [==============================] - 0s 96us/step - loss: 4.9917e-04 - val_loss: 4.9551e-04
# Epoch 31/50
# 250/250 [==============================] - 0s 101us/step - loss: 4.9454e-04 - val_loss: 4.9093e-04
# Epoch 32/50
# 250/250 [==============================] - 0s 95us/step - loss: 4.8998e-04 - val_loss: 4.8643e-04
# Epoch 33/50
# 250/250 [==============================] - 0s 98us/step - loss: 4.8550e-04 - val_loss: 4.8200e-04
# Epoch 34/50
# 250/250 [==============================] - 0s 93us/step - loss: 4.8108e-04 - val_loss: 4.7764e-04
# Epoch 35/50
# 250/250 [==============================] - 0s 101us/step - loss: 4.7674e-04 - val_loss: 4.7335e-04
# Epoch 36/50
# 250/250 [==============================] - 0s 94us/step - loss: 4.7247e-04 - val_loss: 4.6912e-04
# Epoch 37/50
# 250/250 [==============================] - 0s 104us/step - loss: 4.6827e-04 - val_loss: 4.6497e-04
# Epoch 38/50
# 250/250 [==============================] - 0s 91us/step - loss: 4.6413e-04 - val_loss: 4.6088e-04
# Epoch 39/50
# 250/250 [==============================] - 0s 100us/step - loss: 4.6006e-04 - val_loss: 4.5685e-04
# Epoch 40/50
# 250/250 [==============================] - 0s 96us/step - loss: 4.5604e-04 - val_loss: 4.5289e-04
# Epoch 41/50
# 250/250 [==============================] - 0s 99us/step - loss: 4.5209e-04 - val_loss: 4.4898e-04
# Epoch 42/50
# 250/250 [==============================] - 0s 98us/step - loss: 4.4820e-04 - val_loss: 4.4513e-04
# Epoch 43/50
# 250/250 [==============================] - 0s 107us/step - loss: 4.4437e-04 - val_loss: 4.4134e-04
# Epoch 44/50
# 250/250 [==============================] - 0s 100us/step - loss: 4.4059e-04 - val_loss: 4.3760e-04
# Epoch 45/50
# 250/250 [==============================] - 0s 100us/step - loss: 4.3687e-04 - val_loss: 4.3392e-04
# Epoch 46/50
# 250/250 [==============================] - 0s 110us/step - loss: 4.3320e-04 - val_loss: 4.3029e-04
# Epoch 47/50
# 250/250 [==============================] - 0s 98us/step - loss: 4.2959e-04 - val_loss: 4.2671e-04
# Epoch 48/50
# 250/250 [==============================] - 0s 103us/step - loss: 4.2602e-04 - val_loss: 4.2319e-04
# Epoch 49/50
# 250/250 [==============================] - 0s 94us/step - loss: 4.2251e-04 - val_loss: 4.1971e-04
# Epoch 50/50
# 250/250 [==============================] - 0s 103us/step - loss: 4.1905e-04 - val_loss: 4.1628e-04
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 99us/step - loss: 4.1563e-04 - val_loss: 4.1290e-04
# Epoch 2/50
# 250/250 [==============================] - 0s 98us/step - loss: 4.1226e-04 - val_loss: 4.0956e-04
# Epoch 3/50
# 250/250 [==============================] - 0s 105us/step - loss: 4.0893e-04 - val_loss: 4.0627e-04
# Epoch 4/50
# 250/250 [==============================] - 0s 96us/step - loss: 4.0565e-04 - val_loss: 4.0302e-04
# Epoch 5/50
# 250/250 [==============================] - 0s 104us/step - loss: 4.0241e-04 - val_loss: 3.9981e-04
# Epoch 6/50
# 250/250 [==============================] - 0s 98us/step - loss: 3.9921e-04 - val_loss: 3.9665e-04
# Epoch 7/50
# 250/250 [==============================] - 0s 104us/step - loss: 3.9606e-04 - val_loss: 3.9352e-04
# Epoch 8/50
# 250/250 [==============================] - 0s 92us/step - loss: 3.9295e-04 - val_loss: 3.9044e-04
# Epoch 9/50
# 250/250 [==============================] - 0s 99us/step - loss: 3.8987e-04 - val_loss: 3.8739e-04
# Epoch 10/50
# 250/250 [==============================] - 0s 91us/step - loss: 3.8684e-04 - val_loss: 3.8439e-04
# Epoch 11/50
# 250/250 [==============================] - 0s 94us/step - loss: 3.8384e-04 - val_loss: 3.8141e-04
# Epoch 12/50
# 250/250 [==============================] - 0s 90us/step - loss: 3.8088e-04 - val_loss: 3.7848e-04
# Epoch 13/50
# 250/250 [==============================] - 0s 98us/step - loss: 3.7795e-04 - val_loss: 3.7558e-04
# Epoch 14/50
# 250/250 [==============================] - 0s 95us/step - loss: 3.7506e-04 - val_loss: 3.7272e-04
# Epoch 15/50
# 250/250 [==============================] - 0s 89us/step - loss: 3.7221e-04 - val_loss: 3.6989e-04
# Epoch 16/50
# 250/250 [==============================] - 0s 91us/step - loss: 3.6938e-04 - val_loss: 3.6709e-04
# Epoch 17/50
# 250/250 [==============================] - 0s 90us/step - loss: 3.6659e-04 - val_loss: 3.6433e-04
# Epoch 18/50
# 250/250 [==============================] - 0s 94us/step - loss: 3.6384e-04 - val_loss: 3.6160e-04
# Epoch 19/50
# 250/250 [==============================] - 0s 87us/step - loss: 3.6111e-04 - val_loss: 3.5889e-04
# Epoch 20/50
# 250/250 [==============================] - 0s 92us/step - loss: 3.5842e-04 - val_loss: 3.5622e-04
# Epoch 21/50
# 250/250 [==============================] - 0s 98us/step - loss: 3.5575e-04 - val_loss: 3.5358e-04
# Epoch 22/50
# 250/250 [==============================] - 0s 97us/step - loss: 3.5312e-04 - val_loss: 3.5097e-04
# Epoch 23/50
# 250/250 [==============================] - 0s 99us/step - loss: 3.5052e-04 - val_loss: 3.4839e-04
# Epoch 24/50
# 250/250 [==============================] - 0s 99us/step - loss: 3.4794e-04 - val_loss: 3.4583e-04
# Epoch 25/50
# 250/250 [==============================] - 0s 98us/step - loss: 3.4539e-04 - val_loss: 3.4331e-04
# Epoch 26/50
# 250/250 [==============================] - 0s 99us/step - loss: 3.4287e-04 - val_loss: 3.4080e-04
# Epoch 27/50
# 250/250 [==============================] - 0s 101us/step - loss: 3.4037e-04 - val_loss: 3.3833e-04
# Epoch 28/50
# 250/250 [==============================] - 0s 104us/step - loss: 3.3791e-04 - val_loss: 3.3588e-04
# Epoch 29/50
# 250/250 [==============================] - 0s 96us/step - loss: 3.3546e-04 - val_loss: 3.3346e-04
# Epoch 30/50
# 250/250 [==============================] - 0s 98us/step - loss: 3.3305e-04 - val_loss: 3.3106e-04
# Epoch 31/50
# 250/250 [==============================] - 0s 101us/step - loss: 3.3066e-04 - val_loss: 3.2869e-04
# Epoch 32/50
# 250/250 [==============================] - 0s 105us/step - loss: 3.2829e-04 - val_loss: 3.2634e-04
# Epoch 33/50
# 250/250 [==============================] - 0s 93us/step - loss: 3.2594e-04 - val_loss: 3.2402e-04
# Epoch 34/50
# 250/250 [==============================] - 0s 98us/step - loss: 3.2362e-04 - val_loss: 3.2171e-04
# Epoch 35/50
# 250/250 [==============================] - 0s 95us/step - loss: 3.2133e-04 - val_loss: 3.1943e-04
# Epoch 36/50
# 250/250 [==============================] - 0s 95us/step - loss: 3.1905e-04 - val_loss: 3.1718e-04
# Epoch 37/50
# 250/250 [==============================] - 0s 92us/step - loss: 3.1680e-04 - val_loss: 3.1494e-04
# Epoch 38/50
# 250/250 [==============================] - 0s 99us/step - loss: 3.1457e-04 - val_loss: 3.1273e-04
# Epoch 39/50
# 250/250 [==============================] - 0s 97us/step - loss: 3.1236e-04 - val_loss: 3.1053e-04
# Epoch 40/50
# 250/250 [==============================] - 0s 103us/step - loss: 3.1017e-04 - val_loss: 3.0836e-04
# Epoch 41/50
# 250/250 [==============================] - 0s 98us/step - loss: 3.0800e-04 - val_loss: 3.0621e-04
# Epoch 42/50
# 250/250 [==============================] - 0s 103us/step - loss: 3.0586e-04 - val_loss: 3.0408e-04
# Epoch 43/50
# 250/250 [==============================] - 0s 94us/step - loss: 3.0373e-04 - val_loss: 3.0197e-04
# Epoch 44/50
# 250/250 [==============================] - 0s 99us/step - loss: 3.0162e-04 - val_loss: 2.9988e-04
# Epoch 45/50
# 250/250 [==============================] - 0s 97us/step - loss: 2.9954e-04 - val_loss: 2.9781e-04
# Epoch 46/50
# 250/250 [==============================] - 0s 102us/step - loss: 2.9747e-04 - val_loss: 2.9575e-04
# Epoch 47/50
# 250/250 [==============================] - 0s 98us/step - loss: 2.9542e-04 - val_loss: 2.9372e-04
# Epoch 48/50
# 250/250 [==============================] - 0s 97us/step - loss: 2.9339e-04 - val_loss: 2.9170e-04
# Epoch 49/50
# 250/250 [==============================] - 0s 95us/step - loss: 2.9137e-04 - val_loss: 2.8970e-04
# Epoch 50/50
# 250/250 [==============================] - 0s 98us/step - loss: 2.8938e-04 - val_loss: 2.8772e-04
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 84us/step - loss: 2.8740e-04 - val_loss: 2.8576e-04
# Epoch 2/50
# 250/250 [==============================] - 0s 94us/step - loss: 2.8544e-04 - val_loss: 2.8381e-04
# Epoch 3/50
# 250/250 [==============================] - 0s 89us/step - loss: 2.8350e-04 - val_loss: 2.8189e-04
# Epoch 4/50
# 250/250 [==============================] - 0s 93us/step - loss: 2.8158e-04 - val_loss: 2.7997e-04
# Epoch 5/50
# 250/250 [==============================] - 0s 95us/step - loss: 2.7967e-04 - val_loss: 2.7808e-04
# Epoch 6/50
# 250/250 [==============================] - 0s 91us/step - loss: 2.7777e-04 - val_loss: 2.7620e-04
# Epoch 7/50
# 250/250 [==============================] - 0s 99us/step - loss: 2.7590e-04 - val_loss: 2.7434e-04
# Epoch 8/50
# 250/250 [==============================] - 0s 97us/step - loss: 2.7404e-04 - val_loss: 2.7249e-04
# Epoch 9/50
# 250/250 [==============================] - 0s 100us/step - loss: 2.7219e-04 - val_loss: 2.7066e-04
# Epoch 10/50
# 250/250 [==============================] - 0s 100us/step - loss: 2.7037e-04 - val_loss: 2.6884e-04
# Epoch 11/50
# 250/250 [==============================] - 0s 98us/step - loss: 2.6855e-04 - val_loss: 2.6704e-04
# Epoch 12/50
# 250/250 [==============================] - 0s 98us/step - loss: 2.6675e-04 - val_loss: 2.6525e-04
# Epoch 13/50
# 250/250 [==============================] - 0s 98us/step - loss: 2.6497e-04 - val_loss: 2.6348e-04
# Epoch 14/50
# 250/250 [==============================] - 0s 98us/step - loss: 2.6320e-04 - val_loss: 2.6173e-04
# Epoch 15/50
# 250/250 [==============================] - 0s 101us/step - loss: 2.6145e-04 - val_loss: 2.5999e-04
# Epoch 16/50
# 250/250 [==============================] - 0s 103us/step - loss: 2.5971e-04 - val_loss: 2.5826e-04
# Epoch 17/50
# 250/250 [==============================] - 0s 99us/step - loss: 2.5799e-04 - val_loss: 2.5655e-04
# Epoch 18/50
# 250/250 [==============================] - 0s 113us/step - loss: 2.5628e-04 - val_loss: 2.5485e-04
# Epoch 19/50
# 250/250 [==============================] - 0s 102us/step - loss: 2.5458e-04 - val_loss: 2.5316e-04
# Epoch 20/50
# 250/250 [==============================] - 0s 100us/step - loss: 2.5290e-04 - val_loss: 2.5149e-04
# Epoch 21/50
# 250/250 [==============================] - 0s 100us/step - loss: 2.5123e-04 - val_loss: 2.4983e-04
# Epoch 22/50
# 250/250 [==============================] - 0s 91us/step - loss: 2.4957e-04 - val_loss: 2.4818e-04
# Epoch 23/50
# 250/250 [==============================] - 0s 102us/step - loss: 2.4793e-04 - val_loss: 2.4655e-04
# Epoch 24/50
# 250/250 [==============================] - 0s 102us/step - loss: 2.4630e-04 - val_loss: 2.4493e-04
# Epoch 25/50
# 250/250 [==============================] - 0s 106us/step - loss: 2.4468e-04 - val_loss: 2.4333e-04
# Epoch 26/50
# 250/250 [==============================] - 0s 103us/step - loss: 2.4308e-04 - val_loss: 2.4173e-04
# Epoch 27/50
# 250/250 [==============================] - 0s 100us/step - loss: 2.4148e-04 - val_loss: 2.4015e-04
# Epoch 28/50
# 250/250 [==============================] - 0s 92us/step - loss: 2.3991e-04 - val_loss: 2.3858e-04
# Epoch 29/50
# 250/250 [==============================] - 0s 101us/step - loss: 2.3834e-04 - val_loss: 2.3703e-04
# Epoch 30/50
# 250/250 [==============================] - 0s 92us/step - loss: 2.3678e-04 - val_loss: 2.3548e-04
# Epoch 31/50
# 250/250 [==============================] - 0s 94us/step - loss: 2.3524e-04 - val_loss: 2.3395e-04
# Epoch 32/50
# 250/250 [==============================] - 0s 96us/step - loss: 2.3371e-04 - val_loss: 2.3243e-04
# Epoch 33/50
# 250/250 [==============================] - 0s 97us/step - loss: 2.3219e-04 - val_loss: 2.3092e-04
# Epoch 34/50
# 250/250 [==============================] - 0s 92us/step - loss: 2.3069e-04 - val_loss: 2.2942e-04
# Epoch 35/50
# 250/250 [==============================] - 0s 106us/step - loss: 2.2919e-04 - val_loss: 2.2794e-04
# Epoch 36/50
# 250/250 [==============================] - 0s 96us/step - loss: 2.2771e-04 - val_loss: 2.2646e-04
# Epoch 37/50
# 250/250 [==============================] - 0s 102us/step - loss: 2.2624e-04 - val_loss: 2.2500e-04
# Epoch 38/50
# 250/250 [==============================] - 0s 93us/step - loss: 2.2478e-04 - val_loss: 2.2355e-04
# Epoch 39/50
# 250/250 [==============================] - 0s 100us/step - loss: 2.2333e-04 - val_loss: 2.2211e-04
# Epoch 40/50
# 250/250 [==============================] - 0s 93us/step - loss: 2.2189e-04 - val_loss: 2.2068e-04
# Epoch 41/50
# 250/250 [==============================] - 0s 97us/step - loss: 2.2046e-04 - val_loss: 2.1926e-04
# Epoch 42/50
# 250/250 [==============================] - 0s 92us/step - loss: 2.1904e-04 - val_loss: 2.1785e-04
# Epoch 43/50
# 250/250 [==============================] - 0s 101us/step - loss: 2.1763e-04 - val_loss: 2.1645e-04
# Epoch 44/50
# 250/250 [==============================] - 0s 102us/step - loss: 2.1624e-04 - val_loss: 2.1507e-04
# Epoch 45/50
# 250/250 [==============================] - 0s 101us/step - loss: 2.1485e-04 - val_loss: 2.1369e-04
# Epoch 46/50
# 250/250 [==============================] - 0s 94us/step - loss: 2.1348e-04 - val_loss: 2.1232e-04
# Epoch 47/50
# 250/250 [==============================] - 0s 96us/step - loss: 2.1211e-04 - val_loss: 2.1097e-04
# Epoch 48/50
# 250/250 [==============================] - 0s 93us/step - loss: 2.1076e-04 - val_loss: 2.0962e-04
# Epoch 49/50
# 250/250 [==============================] - 0s 96us/step - loss: 2.0941e-04 - val_loss: 2.0828e-04
# Epoch 50/50
# 250/250 [==============================] - 0s 91us/step - loss: 2.0808e-04 - val_loss: 2.0696e-04
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 89us/step - loss: 2.0675e-04 - val_loss: 2.0564e-04
# Epoch 2/50
# 250/250 [==============================] - 0s 92us/step - loss: 2.0544e-04 - val_loss: 2.0433e-04
# Epoch 3/50
# 250/250 [==============================] - 0s 93us/step - loss: 2.0413e-04 - val_loss: 2.0303e-04
# Epoch 4/50
# 250/250 [==============================] - 0s 100us/step - loss: 2.0284e-04 - val_loss: 2.0175e-04
# Epoch 5/50
# 250/250 [==============================] - 0s 95us/step - loss: 2.0155e-04 - val_loss: 2.0047e-04
# Epoch 6/50
# 250/250 [==============================] - 0s 99us/step - loss: 2.0027e-04 - val_loss: 1.9920e-04
# Epoch 7/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.9900e-04 - val_loss: 1.9794e-04
# Epoch 8/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.9775e-04 - val_loss: 1.9669e-04
# Epoch 9/50
# 250/250 [==============================] - 0s 103us/step - loss: 1.9650e-04 - val_loss: 1.9545e-04
# Epoch 10/50
# 250/250 [==============================] - 0s 99us/step - loss: 1.9526e-04 - val_loss: 1.9421e-04
# Epoch 11/50
# 250/250 [==============================] - 0s 100us/step - loss: 1.9403e-04 - val_loss: 1.9299e-04
# Epoch 12/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.9280e-04 - val_loss: 1.9178e-04
# Epoch 13/50
# 250/250 [==============================] - 0s 96us/step - loss: 1.9159e-04 - val_loss: 1.9057e-04
# Epoch 14/50
# 250/250 [==============================] - 0s 99us/step - loss: 1.9038e-04 - val_loss: 1.8937e-04
# Epoch 15/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.8919e-04 - val_loss: 1.8818e-04
# Epoch 16/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.8800e-04 - val_loss: 1.8700e-04
# Epoch 17/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.8682e-04 - val_loss: 1.8583e-04
# Epoch 18/50
# 250/250 [==============================] - 0s 103us/step - loss: 1.8565e-04 - val_loss: 1.8467e-04
# Epoch 19/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.8449e-04 - val_loss: 1.8351e-04
# Epoch 20/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.8333e-04 - val_loss: 1.8236e-04
# Epoch 21/50
# 250/250 [==============================] - 0s 101us/step - loss: 1.8219e-04 - val_loss: 1.8123e-04
# Epoch 22/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.8105e-04 - val_loss: 1.8010e-04
# Epoch 23/50
# 250/250 [==============================] - 0s 107us/step - loss: 1.7992e-04 - val_loss: 1.7897e-04
# Epoch 24/50
# 250/250 [==============================] - 0s 101us/step - loss: 1.7880e-04 - val_loss: 1.7786e-04
# Epoch 25/50
# 250/250 [==============================] - 0s 102us/step - loss: 1.7769e-04 - val_loss: 1.7675e-04
# Epoch 26/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.7658e-04 - val_loss: 1.7565e-04
# Epoch 27/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.7548e-04 - val_loss: 1.7456e-04
# Epoch 28/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.7439e-04 - val_loss: 1.7348e-04
# Epoch 29/50
# 250/250 [==============================] - 0s 101us/step - loss: 1.7331e-04 - val_loss: 1.7240e-04
# Epoch 30/50
# 250/250 [==============================] - 0s 96us/step - loss: 1.7223e-04 - val_loss: 1.7133e-04
# Epoch 31/50
# 250/250 [==============================] - 0s 100us/step - loss: 1.7117e-04 - val_loss: 1.7027e-04
# Epoch 32/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.7011e-04 - val_loss: 1.6922e-04
# Epoch 33/50
# 250/250 [==============================] - 0s 100us/step - loss: 1.6905e-04 - val_loss: 1.6817e-04
# Epoch 34/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.6801e-04 - val_loss: 1.6713e-04
# Epoch 35/50
# 250/250 [==============================] - 0s 111us/step - loss: 1.6697e-04 - val_loss: 1.6610e-04
# Epoch 36/50
# 250/250 [==============================] - 0s 103us/step - loss: 1.6594e-04 - val_loss: 1.6507e-04
# Epoch 37/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.6491e-04 - val_loss: 1.6406e-04
# Epoch 38/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.6390e-04 - val_loss: 1.6304e-04
# Epoch 39/50
# 250/250 [==============================] - 0s 94us/step - loss: 1.6289e-04 - val_loss: 1.6204e-04
# Epoch 40/50
# 250/250 [==============================] - 0s 94us/step - loss: 1.6189e-04 - val_loss: 1.6104e-04
# Epoch 41/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.6089e-04 - val_loss: 1.6005e-04
# Epoch 42/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.5990e-04 - val_loss: 1.5907e-04
# Epoch 43/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.5892e-04 - val_loss: 1.5809e-04
# Epoch 44/50
# 250/250 [==============================] - 0s 96us/step - loss: 1.5794e-04 - val_loss: 1.5712e-04
# Epoch 45/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.5697e-04 - val_loss: 1.5616e-04
# Epoch 46/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.5601e-04 - val_loss: 1.5520e-04
# Epoch 47/50
# 250/250 [==============================] - 0s 104us/step - loss: 1.5506e-04 - val_loss: 1.5425e-04
# Epoch 48/50
# 250/250 [==============================] - 0s 105us/step - loss: 1.5411e-04 - val_loss: 1.5331e-04
# Epoch 49/50
# 250/250 [==============================] - 0s 103us/step - loss: 1.5316e-04 - val_loss: 1.5237e-04
# Epoch 50/50
# 250/250 [==============================] - 0s 103us/step - loss: 1.5223e-04 - val_loss: 1.5144e-04
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 107us/step - loss: 1.5130e-04 - val_loss: 1.5052e-04
# Epoch 2/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.5037e-04 - val_loss: 1.4960e-04
# Epoch 3/50
# 250/250 [==============================] - 0s 99us/step - loss: 1.4946e-04 - val_loss: 1.4869e-04
# Epoch 4/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.4854e-04 - val_loss: 1.4778e-04
# Epoch 5/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.4764e-04 - val_loss: 1.4688e-04
# Epoch 6/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.4674e-04 - val_loss: 1.4599e-04
# Epoch 7/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.4585e-04 - val_loss: 1.4510e-04
# Epoch 8/50
# 250/250 [==============================] - 0s 99us/step - loss: 1.4496e-04 - val_loss: 1.4422e-04
# Epoch 9/50
# 250/250 [==============================] - 0s 101us/step - loss: 1.4408e-04 - val_loss: 1.4334e-04
# Epoch 10/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.4320e-04 - val_loss: 1.4247e-04
# Epoch 11/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.4233e-04 - val_loss: 1.4161e-04
# Epoch 12/50
# 250/250 [==============================] - 0s 94us/step - loss: 1.4147e-04 - val_loss: 1.4075e-04
# Epoch 13/50
# 250/250 [==============================] - 0s 107us/step - loss: 1.4061e-04 - val_loss: 1.3990e-04
# Epoch 14/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.3976e-04 - val_loss: 1.3905e-04
# Epoch 15/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.3891e-04 - val_loss: 1.3821e-04
# Epoch 16/50
# 250/250 [==============================] - 0s 92us/step - loss: 1.3807e-04 - val_loss: 1.3737e-04
# Epoch 17/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.3724e-04 - val_loss: 1.3654e-04
# Epoch 18/50
# 250/250 [==============================] - 0s 92us/step - loss: 1.3641e-04 - val_loss: 1.3572e-04
# Epoch 19/50
# 250/250 [==============================] - 0s 96us/step - loss: 1.3558e-04 - val_loss: 1.3490e-04
# Epoch 20/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.3476e-04 - val_loss: 1.3408e-04
# Epoch 21/50
# 250/250 [==============================] - 0s 91us/step - loss: 1.3395e-04 - val_loss: 1.3328e-04
# Epoch 22/50
# 250/250 [==============================] - 0s 96us/step - loss: 1.3314e-04 - val_loss: 1.3247e-04
# Epoch 23/50
# 250/250 [==============================] - 0s 88us/step - loss: 1.3234e-04 - val_loss: 1.3167e-04
# Epoch 24/50
# 250/250 [==============================] - 0s 91us/step - loss: 1.3154e-04 - val_loss: 1.3088e-04
# Epoch 25/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.3075e-04 - val_loss: 1.3009e-04
# Epoch 26/50
# 250/250 [==============================] - 0s 94us/step - loss: 1.2996e-04 - val_loss: 1.2931e-04
# Epoch 27/50
# 250/250 [==============================] - 0s 104us/step - loss: 1.2918e-04 - val_loss: 1.2853e-04
# Epoch 28/50
# 250/250 [==============================] - 0s 102us/step - loss: 1.2840e-04 - val_loss: 1.2776e-04
# Epoch 29/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.2763e-04 - val_loss: 1.2699e-04
# Epoch 30/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.2687e-04 - val_loss: 1.2623e-04
# Epoch 31/50
# 250/250 [==============================] - 0s 99us/step - loss: 1.2610e-04 - val_loss: 1.2547e-04
# Epoch 32/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.2535e-04 - val_loss: 1.2472e-04
# Epoch 33/50
# 250/250 [==============================] - 0s 92us/step - loss: 1.2459e-04 - val_loss: 1.2398e-04
# Epoch 34/50
# 250/250 [==============================] - 0s 100us/step - loss: 1.2385e-04 - val_loss: 1.2323e-04
# Epoch 35/50
# 250/250 [==============================] - 0s 92us/step - loss: 1.2311e-04 - val_loss: 1.2250e-04
# Epoch 36/50
# 250/250 [==============================] - 0s 101us/step - loss: 1.2237e-04 - val_loss: 1.2176e-04
# Epoch 37/50
# 250/250 [==============================] - 0s 102us/step - loss: 1.2164e-04 - val_loss: 1.2103e-04
# Epoch 38/50
# 250/250 [==============================] - 0s 103us/step - loss: 1.2091e-04 - val_loss: 1.2031e-04
# Epoch 39/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.2018e-04 - val_loss: 1.1959e-04
# Epoch 40/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.1947e-04 - val_loss: 1.1888e-04
# Epoch 41/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.1875e-04 - val_loss: 1.1817e-04
# Epoch 42/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.1804e-04 - val_loss: 1.1746e-04
# Epoch 43/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.1734e-04 - val_loss: 1.1676e-04
# Epoch 44/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.1664e-04 - val_loss: 1.1607e-04
# Epoch 45/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.1594e-04 - val_loss: 1.1538e-04
# Epoch 46/50
# 250/250 [==============================] - 0s 103us/step - loss: 1.1525e-04 - val_loss: 1.1469e-04
# Epoch 47/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.1456e-04 - val_loss: 1.1401e-04
# Epoch 48/50
# 250/250 [==============================] - 0s 103us/step - loss: 1.1388e-04 - val_loss: 1.1333e-04
# Epoch 49/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.1320e-04 - val_loss: 1.1266e-04
# Epoch 50/50
# 250/250 [==============================] - 0s 104us/step - loss: 1.1253e-04 - val_loss: 1.1199e-04
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 98us/step - loss: 1.1186e-04 - val_loss: 1.1132e-04
# Epoch 2/50
# 250/250 [==============================] - 0s 115us/step - loss: 1.1119e-04 - val_loss: 1.1066e-04
# Epoch 3/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.1053e-04 - val_loss: 1.1000e-04
# Epoch 4/50
# 250/250 [==============================] - 0s 104us/step - loss: 1.0988e-04 - val_loss: 1.0935e-04
# Epoch 5/50
# 250/250 [==============================] - 0s 94us/step - loss: 1.0922e-04 - val_loss: 1.0870e-04
# Epoch 6/50
# 250/250 [==============================] - 0s 102us/step - loss: 1.0857e-04 - val_loss: 1.0806e-04
# Epoch 7/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.0793e-04 - val_loss: 1.0742e-04
# Epoch 8/50
# 250/250 [==============================] - 0s 101us/step - loss: 1.0729e-04 - val_loss: 1.0679e-04
# Epoch 9/50
# 250/250 [==============================] - 0s 94us/step - loss: 1.0665e-04 - val_loss: 1.0616e-04
# Epoch 10/50
# 250/250 [==============================] - 0s 100us/step - loss: 1.0602e-04 - val_loss: 1.0553e-04
# Epoch 11/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.0539e-04 - val_loss: 1.0491e-04
# Epoch 12/50
# 250/250 [==============================] - 0s 99us/step - loss: 1.0477e-04 - val_loss: 1.0429e-04
# Epoch 13/50
# 250/250 [==============================] - 0s 99us/step - loss: 1.0415e-04 - val_loss: 1.0367e-04
# Epoch 14/50
# 250/250 [==============================] - 0s 105us/step - loss: 1.0353e-04 - val_loss: 1.0306e-04
# Epoch 15/50
# 250/250 [==============================] - 0s 96us/step - loss: 1.0292e-04 - val_loss: 1.0246e-04
# Epoch 16/50
# 250/250 [==============================] - 0s 96us/step - loss: 1.0231e-04 - val_loss: 1.0185e-04
# Epoch 17/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.0171e-04 - val_loss: 1.0125e-04
# Epoch 18/50
# 250/250 [==============================] - 0s 99us/step - loss: 1.0111e-04 - val_loss: 1.0066e-04
# Epoch 19/50
# 250/250 [==============================] - 0s 94us/step - loss: 1.0051e-04 - val_loss: 1.0007e-04
# Epoch 20/50
# 250/250 [==============================] - 0s 99us/step - loss: 9.9922e-05 - val_loss: 9.9485e-05
# Epoch 21/50
# 250/250 [==============================] - 0s 96us/step - loss: 9.9334e-05 - val_loss: 9.8904e-05
# Epoch 22/50
# 250/250 [==============================] - 0s 99us/step - loss: 9.8749e-05 - val_loss: 9.8327e-05
# Epoch 23/50
# 250/250 [==============================] - 0s 100us/step - loss: 9.8169e-05 - val_loss: 9.7753e-05
# Epoch 24/50
# 250/250 [==============================] - 0s 98us/step - loss: 9.7593e-05 - val_loss: 9.7185e-05
# Epoch 25/50
# 250/250 [==============================] - 0s 98us/step - loss: 9.7020e-05 - val_loss: 9.6620e-05
# Epoch 26/50
# 250/250 [==============================] - 0s 96us/step - loss: 9.6452e-05 - val_loss: 9.6060e-05
# Epoch 27/50
# 250/250 [==============================] - 0s 94us/step - loss: 9.5887e-05 - val_loss: 9.5505e-05
# Epoch 28/50
# 250/250 [==============================] - 0s 95us/step - loss: 9.5327e-05 - val_loss: 9.4954e-05
# Epoch 29/50
# 250/250 [==============================] - 0s 94us/step - loss: 9.4771e-05 - val_loss: 9.4408e-05
# Epoch 30/50
# 250/250 [==============================] - 0s 94us/step - loss: 9.4219e-05 - val_loss: 9.3867e-05
# Epoch 31/50
# 250/250 [==============================] - 0s 94us/step - loss: 9.3671e-05 - val_loss: 9.3331e-05
# Epoch 32/50
# 250/250 [==============================] - 0s 100us/step - loss: 9.3128e-05 - val_loss: 9.2800e-05
# Epoch 33/50
# 250/250 [==============================] - 0s 93us/step - loss: 9.2589e-05 - val_loss: 9.2275e-05
# Epoch 34/50
# 250/250 [==============================] - 0s 94us/step - loss: 9.2055e-05 - val_loss: 9.1756e-05
# Epoch 35/50
# 250/250 [==============================] - 0s 90us/step - loss: 9.1526e-05 - val_loss: 9.1242e-05
# Epoch 36/50
# 250/250 [==============================] - 0s 95us/step - loss: 9.1001e-05 - val_loss: 9.0736e-05
# Epoch 37/50
# 250/250 [==============================] - 0s 91us/step - loss: 9.0482e-05 - val_loss: 9.0236e-05
# Epoch 38/50
# 250/250 [==============================] - 0s 95us/step - loss: 8.9969e-05 - val_loss: 8.9745e-05
# Epoch 39/50
# 250/250 [==============================] - 0s 102us/step - loss: 8.9461e-05 - val_loss: 8.9261e-05
# Epoch 40/50
# 250/250 [==============================] - 0s 97us/step - loss: 8.8960e-05 - val_loss: 8.8787e-05
# Epoch 41/50
# 250/250 [==============================] - 0s 103us/step - loss: 8.8466e-05 - val_loss: 8.8323e-05
# Epoch 42/50
# 250/250 [==============================] - 0s 101us/step - loss: 8.7980e-05 - val_loss: 8.7870e-05
# Epoch 43/50
# 250/250 [==============================] - 0s 101us/step - loss: 8.7502e-05 - val_loss: 8.7430e-05
# Epoch 44/50
# 250/250 [==============================] - 0s 99us/step - loss: 8.7033e-05 - val_loss: 8.7004e-05
# Epoch 45/50
# 250/250 [==============================] - 0s 95us/step - loss: 8.6575e-05 - val_loss: 8.6595e-05
# Epoch 46/50
# 250/250 [==============================] - 0s 104us/step - loss: 8.6128e-05 - val_loss: 8.6204e-05
# Epoch 47/50
# 250/250 [==============================] - 0s 95us/step - loss: 8.5695e-05 - val_loss: 8.5835e-05
# Epoch 48/50
# 250/250 [==============================] - 0s 96us/step - loss: 8.5277e-05 - val_loss: 8.5491e-05
# Epoch 49/50
# 250/250 [==============================] - 0s 95us/step - loss: 8.4877e-05 - val_loss: 8.5175e-05
# Epoch 50/50
# 250/250 [==============================] - 0s 107us/step - loss: 8.4497e-05 - val_loss: 8.4893e-05
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 102us/step - loss: 8.4142e-05 - val_loss: 8.4651e-05
# Epoch 2/50
# 250/250 [==============================] - 0s 95us/step - loss: 8.3814e-05 - val_loss: 8.4454e-05
# Epoch 3/50
# 250/250 [==============================] - 0s 104us/step - loss: 8.3519e-05 - val_loss: 8.4313e-05
# Epoch 4/50
# 250/250 [==============================] - 0s 98us/step - loss: 8.3264e-05 - val_loss: 8.4237e-05
# Epoch 5/50
# 250/250 [==============================] - 0s 101us/step - loss: 8.3054e-05 - val_loss: 8.4237e-05
# Epoch 6/50
# 250/250 [==============================] - 0s 99us/step - loss: 8.2898e-05 - val_loss: 8.4328e-05
# Epoch 7/50
# 250/250 [==============================] - 0s 103us/step - loss: 8.2805e-05 - val_loss: 8.4527e-05
# Epoch 8/50
# 250/250 [==============================] - 0s 94us/step - loss: 8.2788e-05 - val_loss: 8.4853e-05
# Epoch 9/50
# 250/250 [==============================] - 0s 94us/step - loss: 8.2858e-05 - val_loss: 8.5329e-05
# Epoch 10/50
# 250/250 [==============================] - 0s 95us/step - loss: 8.3030e-05 - val_loss: 8.5987e-05
# Epoch 11/50
# 250/250 [==============================] - 0s 97us/step - loss: 8.3323e-05 - val_loss: 8.6853e-05
# Epoch 12/50
# 250/250 [==============================] - 0s 104us/step - loss: 8.3751e-05 - val_loss: 8.7967e-05
# Epoch 13/50
# 250/250 [==============================] - 0s 106us/step - loss: 8.4333e-05 - val_loss: 8.9365e-05
# Epoch 14/50
# 250/250 [==============================] - 0s 99us/step - loss: 8.5086e-05 - val_loss: 9.1085e-05
# Epoch 15/50
# 250/250 [==============================] - 0s 101us/step - loss: 8.6023e-05 - val_loss: 9.3152e-05
# Epoch 16/50
# 250/250 [==============================] - 0s 108us/step - loss: 8.7143e-05 - val_loss: 9.5598e-05
# Epoch 17/50
# 250/250 [==============================] - 0s 99us/step - loss: 8.8443e-05 - val_loss: 9.8392e-05
# Epoch 18/50
# 250/250 [==============================] - 0s 106us/step - loss: 8.9880e-05 - val_loss: 1.0145e-04
# Epoch 19/50
# 250/250 [==============================] - 0s 96us/step - loss: 9.1377e-05 - val_loss: 1.0460e-04
# Epoch 20/50
# 250/250 [==============================] - 0s 102us/step - loss: 9.2811e-05 - val_loss: 1.0754e-04
# Epoch 21/50
# 250/250 [==============================] - 0s 94us/step - loss: 9.3985e-05 - val_loss: 1.0979e-04
# Epoch 22/50
# 250/250 [==============================] - 0s 104us/step - loss: 9.4642e-05 - val_loss: 1.1075e-04
# Epoch 23/50
# 250/250 [==============================] - 0s 98us/step - loss: 9.4487e-05 - val_loss: 1.0981e-04
# Epoch 24/50
# 250/250 [==============================] - 0s 101us/step - loss: 9.3251e-05 - val_loss: 1.0653e-04
# Epoch 25/50
# 250/250 [==============================] - 0s 97us/step - loss: 9.0801e-05 - val_loss: 1.0097e-04
# Epoch 26/50
# 250/250 [==============================] - 0s 97us/step - loss: 8.7263e-05 - val_loss: 9.3809e-05
# Epoch 27/50
# 250/250 [==============================] - 0s 95us/step - loss: 8.3053e-05 - val_loss: 8.6200e-05
# Epoch 28/50
# 250/250 [==============================] - 0s 99us/step - loss: 7.8781e-05 - val_loss: 7.9419e-05
# Epoch 29/50
# 250/250 [==============================] - 0s 96us/step - loss: 7.5068e-05 - val_loss: 7.4339e-05
# Epoch 30/50
# 250/250 [==============================] - 0s 106us/step - loss: 7.2302e-05 - val_loss: 7.1185e-05
# Epoch 31/50
# 250/250 [==============================] - 0s 101us/step - loss: 7.0543e-05 - val_loss: 6.9613e-05
# Epoch 32/50
# 250/250 [==============================] - 0s 99us/step - loss: 6.9585e-05 - val_loss: 6.9019e-05
# Epoch 33/50
# 250/250 [==============================] - 0s 97us/step - loss: 6.9108e-05 - val_loss: 6.8844e-05
# Epoch 34/50
# 250/250 [==============================] - 0s 95us/step - loss: 6.8827e-05 - val_loss: 6.8724e-05
# Epoch 35/50
# 250/250 [==============================] - 0s 102us/step - loss: 6.8565e-05 - val_loss: 6.8501e-05
# ...
# Epoch 7/50
# 250/250 [==============================] - 0s 105us/step - loss: 1.5421e-05 - val_loss: 2.1710e-05
# Epoch 8/50
# 250/250 [==============================] - 0s 92us/step - loss: 1.6418e-05 - val_loss: 2.3479e-05
# Epoch 9/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.7451e-05 - val_loss: 2.5294e-05
# Epoch 10/50
# 250/250 [==============================] - 0s 92us/step - loss: 1.8481e-05 - val_loss: 2.7070e-05
# Epoch 11/50
# 250/250 [==============================] - 0s 95us/step - loss: 1.9451e-05 - val_loss: 2.8688e-05
# Epoch 12/50
# 250/250 [==============================] - 0s 92us/step - loss: 2.0288e-05 - val_loss: 2.9993e-05
# Epoch 13/50
# 250/250 [==============================] - 0s 94us/step - loss: 2.0902e-05 - val_loss: 3.0804e-05
# Epoch 14/50
# 250/250 [==============================] - 0s 90us/step - loss: 2.1198e-05 - val_loss: 3.0945e-05
# Epoch 15/50
# 250/250 [==============================] - 0s 88us/step - loss: 2.1092e-05 - val_loss: 3.0275e-05
# Epoch 16/50
# 250/250 [==============================] - 0s 91us/step - loss: 2.0525e-05 - val_loss: 2.8743e-05
# Epoch 17/50
# 250/250 [==============================] - 0s 89us/step - loss: 1.9494e-05 - val_loss: 2.6420e-05
# Epoch 18/50
# 250/250 [==============================] - 0s 89us/step - loss: 1.8059e-05 - val_loss: 2.3513e-05
# Epoch 19/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.6346e-05 - val_loss: 2.0328e-05
# Epoch 20/50
# 250/250 [==============================] - 0s 89us/step - loss: 1.4526e-05 - val_loss: 1.7204e-05
# Epoch 21/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.2773e-05 - val_loss: 1.4423e-05
# Epoch 22/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.1228e-05 - val_loss: 1.2159e-05
# Epoch 23/50
# 250/250 [==============================] - 0s 97us/step - loss: 9.9735e-06 - val_loss: 1.0456e-05
# Epoch 24/50
# 250/250 [==============================] - 0s 93us/step - loss: 9.0258e-06 - val_loss: 9.2629e-06
# Epoch 25/50
# 250/250 [==============================] - 0s 88us/step - loss: 8.3545e-06 - val_loss: 8.4765e-06
# Epoch 26/50
# 250/250 [==============================] - 0s 96us/step - loss: 7.9036e-06 - val_loss: 7.9829e-06
# Epoch 27/50
# 250/250 [==============================] - 0s 90us/step - loss: 7.6136e-06 - val_loss: 7.6864e-06
# Epoch 28/50
# 250/250 [==============================] - 0s 88us/step - loss: 7.4342e-06 - val_loss: 7.5177e-06
# Epoch 29/50
# 250/250 [==============================] - 0s 90us/step - loss: 7.3287e-06 - val_loss: 7.4321e-06
# Epoch 30/50
# 250/250 [==============================] - 0s 88us/step - loss: 7.2727e-06 - val_loss: 7.4029e-06
# Epoch 31/50
# 250/250 [==============================] - 0s 91us/step - loss: 7.2513e-06 - val_loss: 7.4150e-06
# Epoch 32/50
# 250/250 [==============================] - 0s 90us/step - loss: 7.2556e-06 - val_loss: 7.4600e-06
# Epoch 33/50
# 250/250 [==============================] - 0s 89us/step - loss: 7.2804e-06 - val_loss: 7.5332e-06
# Epoch 34/50
# 250/250 [==============================] - 0s 92us/step - loss: 7.3228e-06 - val_loss: 7.6326e-06
# Epoch 35/50
# 250/250 [==============================] - 0s 92us/step - loss: 7.3815e-06 - val_loss: 7.7575e-06
# Epoch 36/50
# 250/250 [==============================] - 0s 92us/step - loss: 7.4562e-06 - val_loss: 7.9084e-06
# Epoch 37/50
# 250/250 [==============================] - 0s 99us/step - loss: 7.5473e-06 - val_loss: 8.0876e-06
# Epoch 38/50
# 250/250 [==============================] - 0s 100us/step - loss: 7.6563e-06 - val_loss: 8.2978e-06
# Epoch 39/50
# 250/250 [==============================] - 0s 101us/step - loss: 7.7852e-06 - val_loss: 8.5431e-06
# Epoch 40/50
# 250/250 [==============================] - 0s 96us/step - loss: 7.9368e-06 - val_loss: 8.8288e-06
# Epoch 41/50
# 250/250 [==============================] - 0s 99us/step - loss: 8.1146e-06 - val_loss: 9.1610e-06
# Epoch 42/50
# 250/250 [==============================] - 0s 102us/step - loss: 8.3225e-06 - val_loss: 9.5467e-06
# Epoch 43/50
# 250/250 [==============================] - 0s 96us/step - loss: 8.5652e-06 - val_loss: 9.9941e-06
# Epoch 44/50
# 250/250 [==============================] - 0s 103us/step - loss: 8.8480e-06 - val_loss: 1.0513e-05
# Epoch 45/50
# 250/250 [==============================] - 0s 94us/step - loss: 9.1769e-06 - val_loss: 1.1113e-05
# Epoch 46/50
# 250/250 [==============================] - 0s 102us/step - loss: 9.5582e-06 - val_loss: 1.1805e-05
# Epoch 47/50
# 250/250 [==============================] - 0s 94us/step - loss: 9.9989e-06 - val_loss: 1.2603e-05
# Epoch 48/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.0506e-05 - val_loss: 1.3518e-05
# Epoch 49/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.1087e-05 - val_loss: 1.4564e-05
# Epoch 50/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.1747e-05 - val_loss: 1.5751e-05
# ----------------actual samples
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 85us/step - loss: 1.2492e-05 - val_loss: 1.7086e-05
# Epoch 2/50
# 250/250 [==============================] - 0s 100us/step - loss: 1.3322e-05 - val_loss: 1.8571e-05
# Epoch 3/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.4233e-05 - val_loss: 2.0198e-05
# Epoch 4/50
# 250/250 [==============================] - 0s 92us/step - loss: 1.5215e-05 - val_loss: 2.1943e-05
# Epoch 5/50
# 250/250 [==============================] - 0s 91us/step - loss: 1.6247e-05 - val_loss: 2.3761e-05
# Epoch 6/50
# 250/250 [==============================] - 0s 92us/step - loss: 1.7294e-05 - val_loss: 2.5580e-05
# Epoch 7/50
# 250/250 [==============================] - 0s 94us/step - loss: 1.8306e-05 - val_loss: 2.7293e-05
# Epoch 8/50
# 250/250 [==============================] - 0s 89us/step - loss: 1.9214e-05 - val_loss: 2.8754e-05
# Epoch 9/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.9934e-05 - val_loss: 2.9789e-05
# Epoch 10/50
# 250/250 [==============================] - 0s 89us/step - loss: 2.0370e-05 - val_loss: 3.0213e-05
# Epoch 11/50
# 250/250 [==============================] - 0s 90us/step - loss: 2.0429e-05 - val_loss: 2.9864e-05
# Epoch 12/50
# 250/250 [==============================] - 0s 91us/step - loss: 2.0041e-05 - val_loss: 2.8648e-05
# Epoch 13/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.9176e-05 - val_loss: 2.6589e-05
# Epoch 14/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.7873e-05 - val_loss: 2.3849e-05
# Epoch 15/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.6236e-05 - val_loss: 2.0709e-05
# Epoch 16/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.4426e-05 - val_loss: 1.7513e-05
# Epoch 17/50
# 250/250 [==============================] - 0s 108us/step - loss: 1.2625e-05 - val_loss: 1.4575e-05
# Epoch 18/50
# 250/250 [==============================] - 0s 91us/step - loss: 1.0991e-05 - val_loss: 1.2114e-05
# Epoch 19/50
# 250/250 [==============================] - 0s 90us/step - loss: 9.6296e-06 - val_loss: 1.0220e-05
# Epoch 20/50
# 250/250 [==============================] - 0s 90us/step - loss: 8.5801e-06 - val_loss: 8.8670e-06
# Epoch 21/50
# 250/250 [==============================] - 0s 91us/step - loss: 7.8244e-06 - val_loss: 7.9623e-06
# Epoch 22/50
# 250/250 [==============================] - 0s 91us/step - loss: 7.3113e-06 - val_loss: 7.3891e-06
# Epoch 23/50
# 250/250 [==============================] - 0s 89us/step - loss: 6.9792e-06 - val_loss: 7.0422e-06
# Epoch 24/50
# 250/250 [==============================] - 0s 88us/step - loss: 6.7731e-06 - val_loss: 6.8426e-06
# Epoch 25/50
# 250/250 [==============================] - 0s 96us/step - loss: 6.6511e-06 - val_loss: 6.7375e-06
# Epoch 26/50
# 250/250 [==============================] - 0s 98us/step - loss: 6.5849e-06 - val_loss: 6.6948e-06
# Epoch 27/50
# 250/250 [==============================] - 0s 90us/step - loss: 6.5568e-06 - val_loss: 6.6964e-06
# Epoch 28/50
# 250/250 [==============================] - 0s 99us/step - loss: 6.5560e-06 - val_loss: 6.7318e-06
# Epoch 29/50
# 250/250 [==============================] - 0s 92us/step - loss: 6.5765e-06 - val_loss: 6.7957e-06
# Epoch 30/50
# 250/250 [==============================] - 0s 91us/step - loss: 6.6148e-06 - val_loss: 6.8852e-06
# Epoch 31/50
# 250/250 [==============================] - 0s 91us/step - loss: 6.6691e-06 - val_loss: 6.9992e-06
# Epoch 32/50
# 250/250 [==============================] - 0s 89us/step - loss: 6.7386e-06 - val_loss: 7.1379e-06
# Epoch 33/50
# 250/250 [==============================] - 0s 91us/step - loss: 6.8237e-06 - val_loss: 7.3027e-06
# Epoch 34/50
# 250/250 [==============================] - 0s 89us/step - loss: 6.9254e-06 - val_loss: 7.4963e-06
# Epoch 35/50
# 250/250 [==============================] - 0s 91us/step - loss: 7.0454e-06 - val_loss: 7.7224e-06
# Epoch 36/50
# 250/250 [==============================] - 0s 90us/step - loss: 7.1865e-06 - val_loss: 7.9857e-06
# Epoch 37/50
# 250/250 [==============================] - 0s 89us/step - loss: 7.3517e-06 - val_loss: 8.2916e-06
# Epoch 38/50
# 250/250 [==============================] - 0s 91us/step - loss: 7.5446e-06 - val_loss: 8.6470e-06
# Epoch 39/50
# 250/250 [==============================] - 0s 90us/step - loss: 7.7698e-06 - val_loss: 9.0596e-06
# Epoch 40/50
# 250/250 [==============================] - 0s 89us/step - loss: 8.0321e-06 - val_loss: 9.5378e-06
# Epoch 41/50
# 250/250 [==============================] - 0s 90us/step - loss: 8.3372e-06 - val_loss: 1.0092e-05
# Epoch 42/50
# 250/250 [==============================] - 0s 91us/step - loss: 8.6916e-06 - val_loss: 1.0733e-05
# Epoch 43/50
# 250/250 [==============================] - 0s 90us/step - loss: 9.1019e-06 - val_loss: 1.1473e-05
# Epoch 44/50
# 250/250 [==============================] - 0s 90us/step - loss: 9.5758e-06 - val_loss: 1.2326e-05
# Epoch 45/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.0121e-05 - val_loss: 1.3304e-05
# Epoch 46/50
# 250/250 [==============================] - 0s 102us/step - loss: 1.0743e-05 - val_loss: 1.4420e-05
# Epoch 47/50
# 250/250 [==============================] - 0s 91us/step - loss: 1.1449e-05 - val_loss: 1.5685e-05
# Epoch 48/50
# 250/250 [==============================] - 0s 109us/step - loss: 1.2243e-05 - val_loss: 1.7104e-05
# Epoch 49/50
# 250/250 [==============================] - 0s 94us/step - loss: 1.3124e-05 - val_loss: 1.8676e-05
# Epoch 50/50
# 250/250 [==============================] - 0s 91us/step - loss: 1.4085e-05 - val_loss: 2.0388e-05
# ----------------noise
# Train on 250 samples, validate on 250 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 83us/step - loss: 4.2931e-05 - val_loss: 4.5019e-05
# Epoch 2/50
# 250/250 [==============================] - 0s 102us/step - loss: 3.9793e-05 - val_loss: 4.1464e-05
# Epoch 3/50
# 250/250 [==============================] - 0s 89us/step - loss: 3.6455e-05 - val_loss: 3.8022e-05
# Epoch 4/50
# 250/250 [==============================] - 0s 89us/step - loss: 3.3559e-05 - val_loss: 3.6094e-05
# Epoch 5/50
# 250/250 [==============================] - 0s 88us/step - loss: 3.1731e-05 - val_loss: 3.5043e-05
# Epoch 6/50
# 250/250 [==============================] - 0s 90us/step - loss: 3.0737e-05 - val_loss: 3.5210e-05
# Epoch 7/50
# 250/250 [==============================] - 0s 91us/step - loss: 3.0488e-05 - val_loss: 3.5115e-05
# Epoch 8/50
# 250/250 [==============================] - 0s 90us/step - loss: 3.0046e-05 - val_loss: 3.5011e-05
# Epoch 9/50
# 250/250 [==============================] - 0s 91us/step - loss: 2.9626e-05 - val_loss: 3.4580e-05
# Epoch 10/50
# 250/250 [==============================] - 0s 96us/step - loss: 2.9111e-05 - val_loss: 3.3976e-05
# Epoch 11/50
# 250/250 [==============================] - 0s 92us/step - loss: 2.8511e-05 - val_loss: 3.2987e-05
# Epoch 12/50
# 250/250 [==============================] - 0s 94us/step - loss: 2.7708e-05 - val_loss: 3.2074e-05
# Epoch 13/50
# 250/250 [==============================] - 0s 89us/step - loss: 2.6938e-05 - val_loss: 3.1111e-05
# Epoch 14/50
# 250/250 [==============================] - 0s 112us/step - loss: 2.6230e-05 - val_loss: 3.0205e-05
# Epoch 15/50
# 250/250 [==============================] - 0s 94us/step - loss: 2.5562e-05 - val_loss: 2.9117e-05
# Epoch 16/50
# 250/250 [==============================] - 0s 94us/step - loss: 2.4797e-05 - val_loss: 2.7979e-05
# Epoch 17/50
# 250/250 [==============================] - 0s 92us/step - loss: 2.4016e-05 - val_loss: 2.6738e-05
# Epoch 18/50
# 250/250 [==============================] - 0s 92us/step - loss: 2.3220e-05 - val_loss: 2.5520e-05
# Epoch 19/50
# 250/250 [==============================] - 0s 94us/step - loss: 2.2440e-05 - val_loss: 2.4338e-05
# Epoch 20/50
# 250/250 [==============================] - 0s 89us/step - loss: 2.1675e-05 - val_loss: 2.3356e-05
# Epoch 21/50
# 250/250 [==============================] - 0s 90us/step - loss: 2.1039e-05 - val_loss: 2.2546e-05
# Epoch 22/50
# 250/250 [==============================] - 0s 87us/step - loss: 2.0535e-05 - val_loss: 2.1890e-05
# Epoch 23/50
# 250/250 [==============================] - 0s 90us/step - loss: 2.0122e-05 - val_loss: 2.1319e-05
# Epoch 24/50
# 250/250 [==============================] - 0s 88us/step - loss: 1.9750e-05 - val_loss: 2.0859e-05
# Epoch 25/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.9441e-05 - val_loss: 2.0482e-05
# Epoch 26/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.9195e-05 - val_loss: 2.0202e-05
# Epoch 27/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.9002e-05 - val_loss: 1.9997e-05
# Epoch 28/50
# 250/250 [==============================] - 0s 89us/step - loss: 1.8849e-05 - val_loss: 1.9888e-05
# Epoch 29/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.8757e-05 - val_loss: 1.9854e-05
# Epoch 30/50
# 250/250 [==============================] - 0s 88us/step - loss: 1.8722e-05 - val_loss: 1.9874e-05
# Epoch 31/50
# 250/250 [==============================] - 0s 97us/step - loss: 1.8717e-05 - val_loss: 1.9910e-05
# Epoch 32/50
# 250/250 [==============================] - 0s 89us/step - loss: 1.8714e-05 - val_loss: 1.9980e-05
# Epoch 33/50
# 250/250 [==============================] - 0s 88us/step - loss: 1.8730e-05 - val_loss: 2.0091e-05
# Epoch 34/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.8778e-05 - val_loss: 2.0245e-05
# Epoch 35/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.8853e-05 - val_loss: 2.0430e-05
# Epoch 36/50
# 250/250 [==============================] - 0s 93us/step - loss: 1.8944e-05 - val_loss: 2.0657e-05
# Epoch 37/50
# 250/250 [==============================] - 0s 86us/step - loss: 1.9060e-05 - val_loss: 2.0919e-05
# Epoch 38/50
# 250/250 [==============================] - 0s 89us/step - loss: 1.9203e-05 - val_loss: 2.1204e-05
# Epoch 39/50
# 250/250 [==============================] - 0s 90us/step - loss: 1.9358e-05 - val_loss: 2.1500e-05
# Epoch 40/50
# 250/250 [==============================] - 0s 88us/step - loss: 1.9515e-05 - val_loss: 2.1816e-05
# Epoch 41/50
# 250/250 [==============================] - 0s 92us/step - loss: 1.9683e-05 - val_loss: 2.2160e-05
# Epoch 42/50
# 250/250 [==============================] - 0s 86us/step - loss: 1.9869e-05 - val_loss: 2.2527e-05
# Epoch 43/50
# 250/250 [==============================] - 0s 89us/step - loss: 2.0069e-05 - val_loss: 2.2899e-05
# Epoch 44/50
# 250/250 [==============================] - 0s 89us/step - loss: 2.0267e-05 - val_loss: 2.3274e-05
# Epoch 45/50
# 250/250 [==============================] - 0s 88us/step - loss: 2.0463e-05 - val_loss: 2.3644e-05
# Epoch 46/50
# 250/250 [==============================] - 0s 88us/step - loss: 2.0654e-05 - val_loss: 2.3993e-05
# Epoch 47/50
# 250/250 [==============================] - 0s 91us/step - loss: 2.0830e-05 - val_loss: 2.4309e-05
# Epoch 48/50
# 250/250 [==============================] - 0s 89us/step - loss: 2.0978e-05 - val_loss: 2.4584e-05
# Epoch 49/50
# 250/250 [==============================] - 0s 89us/step - loss: 2.1098e-05 - val_loss: 2.4814e-05
# Epoch 50/50
# 250/250 [==============================] - 0s 90us/step - loss: 2.1188e-05 - val_loss: 2.4983e-05

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(X_train_scaled)
ax.plot(range(0,len(losses)), losses, '-', color='blue', animated = True, linewidth=1)

# %% [markdown]
# ### Test Datasets

# %%
# initial condition
def testDynamics(test_data):
    X_test_scaled = scaler.transform(test_data)
    X_test_scaled = X_test_scaled.reshape(int(samples/timesteps),timesteps,dim)
    yhat_predict = mod_2.predict(X_test_scaled)
    yhat_predict = yhat_predict.reshape(samples,dim)
    yhat_rescaled = scaler.inverse_transform(yhat_predict)
    plotComparison(test_data, 'Exact Dynamics', yhat_rescaled, 'Learnt Dynamics')

# %%
testDynamics(_data_train)

# %%
_data_test_one = simulate(time_points, x0, 0, 28.5, 2.2, 45)
testDynamics(_data_test_one)

# %%
time_points = np.arange(0,25,0.01)
_data_test_two = simulate(time_points, x0, 0, 33.5, 2.5, 18.5)
testDynamics(_data_test_two)

# %%
_data_test_three = simulate(time_points, x0, 0, 23.0, 5.9, 34.5)
testDynamics(_data_test_three )

# %% [markdown]
# ## Complex Valued networks

# %% [markdown]
# ### Complex RNN

# %%
tf.reset_default_graph()

n_steps = 10 #number of periods per vector we are using to predict one period ahead
n_inputs = 3 #number of vectors submitted
n_neurons = 100 #number of neurons we will recursively work through, can be changed to improve accuracy
n_outputs = 3 #number of output vectors

X = tf.placeholder(tf.float32, [None, n_steps, n_inputs])
y = tf.placeholder(tf.float32, [None, n_steps, n_outputs])

#basic_cell = rnn.BasicRNNCell(num_units=n_neurons, activation=tf.nn.relu)
cell = ComplexRNNCell(n_neurons, 2)
hidden_out_comp, states = tf.nn.dynamic_rnn(cell, X, dtype=tf.complex64) #Choose dynamic over static
rnn_outputs = tf.real(hidden_out_comp)


learning_rate = 3e-5 # Small learning rate so we don't overshoot the minimum

stacked_rnn_outputs = tf.reshape(rnn_outputs, [-1, n_neurons]) #change the form into a tensor
stacked_outputs = tf.layers.dense(stacked_rnn_outputs, n_outputs) #specify the type of layers
outputs = tf.reshape(stacked_outputs, [-1, n_steps, n_outputs]) #shape of results

loss = tf.reduce_mean(tf.square(outputs-y)) #define the cost function

optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate, decay=0.7) #gradient descent method
training_op = optimizer.minimize(loss) #train the result of the application of the cost function

init = tf.global_variables_initializer() # initialize all the variables

# %%
def reshape_dataset(data_set):
    data_set = data_set.reshape(int(samples/timesteps),timesteps,dim)
    return data_set
train_data = reshape_dataset(_data_train)
x_batches, y_batches = train_data, train_data
test_one = reshape_dataset(_data_test_one)
test_two = reshape_dataset(_data_test_two)
test_three = reshape_dataset(_data_test_three)

# %%
n_iterations =2500
batch_size = 50
with tf.Session() as sess:
    init.run()
    for iteration in range(n_iterations):
        sess.run(training_op, feed_dict={X: x_batches, y: y_batches})
        if iteration % 100 == 0:
            mse = loss.eval(feed_dict={X: x_batches, y: y_batches})
            print(iteration, "\MSE:", mse)
            
    y_pred_one = sess.run(outputs, feed_dict={X: test_one})
    y_pred_two = sess.run(outputs, feed_dict={X: test_two})
    y_pred_three = sess.run(outputs, feed_dict={X: test_three})
# Out:
# 0 \MSE: 870.47107
# 100 \MSE: 598.3482
# 200 \MSE: 399.68066
# 300 \MSE: 264.00943
# 400 \MSE: 181.44579
# 500 \MSE: 132.43254
# 600 \MSE: 97.425095
# 700 \MSE: 71.13039
# 800 \MSE: 51.821445
# 900 \MSE: 38.033535
# 1000 \MSE: 28.381521
# 1100 \MSE: 21.32711
# 1200 \MSE: 15.79951
# 1300 \MSE: 11.444911
# 1400 \MSE: 8.109645
# 1500 \MSE: 5.655884
# 1600 \MSE: 3.911937
# 1700 \MSE: 2.693803
# 1800 \MSE: 1.8499888
# 1900 \MSE: 1.2556754
# 2000 \MSE: 0.8429596
# 2100 \MSE: 0.572379
# 2200 \MSE: 0.4032995
# 2300 \MSE: 0.2963832
# 2400 \MSE: 0.2244446

# %%
# initial condition
def test_dynamics_complex(test_data, yhat):
    yhat.shape = (samples, dim)
    test_data.shape = (samples, dim)
    plotComparison(test_data, 'Exact Dynamics', yhat, 'Learnt Dynamics')
    
test_dynamics_complex(test_one, y_pred_one)

# %%
test_dynamics_complex(test_two, y_pred_two)
